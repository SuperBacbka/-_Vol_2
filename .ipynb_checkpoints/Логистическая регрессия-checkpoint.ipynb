# %%
import numpy as np
import pandas as pd

# %%
Data_Train = pd.read_csv("train.csv", sep=",", low_memory=False)
Data_Test  = pd.read_csv("valid.csv", sep=",", low_memory=False)

# %%
Data_Train.head()
# Out:
#   report_date  client_id  target  col1  col2  col3  col4  col5  col6  col7  \
# 0  2022-11-01          1       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2022-11-01          5       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2022-05-01          6       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  2022-09-01          7       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2022-08-01          8       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...    col2654    col2655    col2656  col2657  col2658  col2659    col2660  \
# 0  ...        NaN        NaN        NaN      NaN      NaN      NaN        NaN
# 1  ...  7616803.0  7616803.0  7616803.0      NaN      NaN      NaN  7616803.0
# 2  ...        NaN        NaN        NaN      NaN      NaN      NaN        NaN
# 3  ...        NaN        NaN        NaN      NaN      NaN      NaN        NaN
# 4  ...        NaN        NaN        NaN      NaN      NaN      NaN        NaN
#
#      col2661    col2662   col2663
# 0        NaN        NaN  0.256261
# 1  7616803.0  7616803.0  0.256261
# 2        NaN        NaN  0.256261
# 3        NaN        NaN  0.258682
# 4        NaN        NaN  0.254164
#
# [5 rows x 2666 columns]

# %%
print(f"В Датафрейме Train Строк:{Data_Train.shape[0]} Колонок: {Data_Train.shape[1]}")
# Out:
# В Датафрейме Train Строк:14456 Колонок: 2666

# %%
Data_Test.head()
# Out:
#   report_date  client_id  target  col1  col2  col3  col4  col5  col6  col7  \
# 0  2023-04-01          2       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2023-05-01          4       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2023-05-01          9       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  2023-03-01         12       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2023-03-01         14       0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...     col2654     col2655     col2656  col2657  col2658  col2659  \
# 0  ...   4941670.0   4941670.0   4941670.0      NaN      NaN      NaN
# 1  ...  11789500.0  11789500.0  11789500.0      NaN      NaN      NaN
# 2  ...   7000000.0   7000000.0   7000000.0      NaN      NaN      NaN
# 3  ...         NaN         NaN         NaN      NaN      NaN      NaN
# 4  ...         NaN         NaN         NaN      NaN      NaN      NaN
#
#       col2660     col2661     col2662   col2663
# 0   4941670.0   4941670.0   4941670.0  0.256919
# 1  11789500.0  11789500.0  11789500.0  0.267221
# 2   7000000.0   7000000.0   7000000.0  0.257217
# 3         NaN         NaN         NaN  0.256261
# 4  10391000.0  10391000.0  10391000.0  0.257348
#
# [5 rows x 2666 columns]

# %%
print(f"В Датафрейме Test Строк:{Data_Test.shape[0]} Колонок: {Data_Test.shape[1]}")
# Out:
# В Датафрейме Test Строк:3642 Колонок: 2666

# %% [markdown]
# ### Большие датасеты. Посмотрим сколько колонок с пропуском более 50%

# %%
colums_is_nul = Data_Test.isnull().mean() * 100 
columns_show = colums_is_nul[colums_is_nul > 0.5]

print("-" * 60)
print(f"Количество колонок в Test с более чем 50% пропусков: {len(columns_show)}")
# Out:
# ------------------------------------------------------------
# Количество колонок в Test с более чем 50% пропусков: 2426

# %%
colums_is_nul = Data_Train.isnull().mean() * 100 
columns_show = colums_is_nul[colums_is_nul > 0.5]
print(f"Количество колонок в Train с более чем 50% пропусков: {len(columns_show)}")
# Out:
# Количество колонок в Train с более чем 50% пропусков: 2618

# %% [markdown]
# Давольно много пропусков

# %% [markdown]
# ### Попробуем визуализировать пропуски

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#fig, ax = plt.subplots(figsize=(11, 11))
#sns.heatmap(Data_Train.isnull(), cmap='cividis', cbar = False)

#plt.show()

# %%
#fig, ax = plt.subplots(figsize=(11, 11))
#sns.heatmap(Data_Test.isnull(), cmap='cividis', cbar = False)

#plt.show()

# %% [markdown]
# ### Давольно трудно Визуализировать такой объём данных, но видно что есть колонки в которых почти 100% пропуски, эксперт в предметной области сообщил, что 100% пропуски это не поступившие данные, а 99% могут быть дамми переменными, так же обратим внимание на описание к данным
#
#
# train.csv - sample данных обучающего датасета. Есть колонки report_date (дата среза признаков), client_id (уникальный идентификатор клиента), target. Названия остальных колонок зашифрованы и представляют собой признаковое пространство для моделирования.
#
# test.csv - sample данных тестового датасета. Есть колонки report_date (дата среза признаков) и client_id (уникальный идентификатор клиента).  Названия остальных колонок зашифрованы и представляют собой признаковое пространство для скоринг
#
# #### Таким образом с уверености мы можем сказать лишь о 3-х колонках
#   * report_date
#   * client_id
#   * target
# #### Ещё с помощью test мы будем тестировать нашу модель, это данные которые модель ни когда не видела, таким образом мы можем избежать утечки данных  а.

# %% [markdown]
# Давайте разделим колонки На числовые и текстовые и ппробуем обработать их отдельно

# %%
Data_Train_Object = Data_Train.select_dtypes(include="object")
Data_Train_numeric = Data_Train.select_dtypes(exclude="object")

# %%
Data_Test_Object = Data_Test.select_dtypes(include="object")
Data_Test_numeric = Data_Test.select_dtypes(exclude="object")

# %% [markdown]
# #### Взгляенм на уникальные значения текстовых колонок

# %%
for colum  in Data_Train_Object.columns:
    
    unique_values = Data_Train_Object[colum].dropna().unique()
    print(f"Колонка : {colum}")
    print(f"Количество уникальных значений: {len(unique_values)}")
    print(f"Уникальные значения: {unique_values}")
    print("-" * 50)
# Out:
# Колонка : report_date
# Количество уникальных значений: 25
# Уникальные значения: ['2022-11-01' '2022-05-01' '2022-09-01' '2022-08-01' '2023-02-01'
#  '2023-01-01' '2022-02-01' '2022-12-01' '2022-06-01' '2022-10-01'
#  '2021-08-01' '2021-05-01' '2022-04-01' '2022-03-01' '2022-07-01'
#  '2021-10-01' '2021-02-01' '2022-01-01' '2021-12-01' '2021-04-01'
#  '2021-06-01' '2021-11-01' '2021-07-01' '2021-09-01' '2021-03-01']
# --------------------------------------------------
# Колонка : col49
# Количество уникальных значений: 5
# Уникальные значения: ['https://samolet.ru/commercial/'
#  'https://samolet.ru/spb/?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet_yd_s_brand_spb_common_search_search_samolet_text_spb-lo_33~yzizmzuw|70577427&utm_term=%D1%81%D0%B0%D0%BC%D0%BE%D0%BB%D0%B5%D1%82&utm_content=38601006397_|cid|70577427|gid|4903321849|aid|12096120121|adp|no|pos|premium1|src|search_none|dvc|mobile|reg|2|text_otdelka&calltouch_tm=yd_c:70577427_gb:4903321849_ad:12096120121_ph:38601006397_st:search_pt:premium_p:1_s:none_dt:mobile_reg:2_ret:_apt:none&yadclid=95349662&yadordid=170577427&yclid=9024159213120651263'
#  'https://samolet.ru/'
#  'https://samolet.ru/?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet_live_yd_s_brand_samoletgroup_search_search_samolet_text_mmo_33~mzywztjh|68613244&utm_term=%D0%B3%D0%BA%20%D1%81%D0%B0%D0%BC%D0%BE%D0%BB%D0%B5%D1%82&utm_content=35325882672_|cid|68613244|gid|4767846383|aid|11492307715|adp|no|pos|premium1|src|search_none|dvc|mobile|reg
?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet_yd_s_brand_spb_common_search_search_samolet_text_spb-lo_33~yzizmzuw|70577427&utm_term=%D0%B6%D0%BA%20%D1%81%D0%B0%D0%BC%D0%BE%D0%BB%D0%B5%D1%82%20%D1%81%D0%B0%D0%BD%D0%BA%D1%82%20%D0%BF%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3&utm_content=38396738368_|cid|70577427|gid|4810189389|aid|11685225711|adp|no|pos|premium1|src|search_none|dvc|mobile|reg|98634|text_cena&calltouch_tm=yd_c:70577427_gb:4810189389_ad:11685225711_ph:38396738368_st:search_pt:premium_p:1_s:none_dt:mobile_reg:98634_ret:_apt:none&yclid=15241513409759150079']
# --------------------------------------------------
# Колонка : col57
# Количество уникальных значений: 3
# Уникальные значения: ['comm-main' 'main' 'projects_page']
# --------------------------------------------------
# Колонка : col58
# Количество уникальных значений: 3
# Уникальные значения: ['main' 'projects_page' 'comm-main']
# --------------------------------------------------
# Колонка : col59
# Количество уникальных значений: 3
# Уникальные значения: ['main' 'projects_page' 'comm-main']
# --------------------------------------------------
# Колонка : col60
# Количество уникальных значений: 3
# Уникальные значения: ['projects_page' 'main' 'comm-main']
# --------------------------------------------------
# Колонка : col61
# Количество уникальных значений: 3
# Уникальные значения: ['comm-main' 'main' 'projects_page']
# --------------------------------------------------
# Колонка : col62
# Количество уникальных значений: 3
# Уникальные значения: ['main' 'projects_page' 'comm-main']
# --------------------------------------------------
# Колонка : col63
# Количество уникальных значений: 3
# Уникальные значения: ['main' 'projects_page' 'comm-main']
# --------------------------------------------------
# Колонка : col64
# Количество уникальных значений: 3
# Уникальные значения: ['projects_page' 'main' 'comm-main']
# --------------------------------------------------
# Колонка : col85
# Количество уникальных значений: 2
# Уникальные значения: ['off' 'on']
# --------------------------------------------------
# Колонка : col86
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col87
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col88
# Количество уникальных значений: 2
# Уникальные значения: ['off' 'on']
# --------------------------------------------------
# Колонка : col89
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col90
# Количество уникальных значений: 2
# Уникальные значения: ['off' 'on']
# --------------------------------------------------
# Колонка : col91
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col92
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col93
# Количество уникальных значений: 3
# Уникальные значения: ['apt_kitchen' 'apt_storage' 'apt_furniture']
# --------------------------------------------------
# Колонка : col94
# Количество уникальных значений: 4
# Уникальные значения: ['apt_furniture' 'apt_kitchen' 'apt_storage' 'apt_decor']
# --------------------------------------------------
# Колонка : col95
# Количество уникальных значений: 5
# Уникальные значения: ['apt_furniture' 'apt_conditioner' 'apt_kitchen' 'apt_storage' 'apt_decor']
# --------------------------------------------------
# Колонка : col96
# Количество уникальных значений: 6
# Уникальные значения: ['apt_furniture' 'apt_kitchen' 'apt_conditioner' 'apt_storage' 'apt_decor'
#  'apt_description']
# --------------------------------------------------
# Колонка : col97
# Количество уникальных значений: 4
# Уникальные значения: ['apt_kitchen' 'apt_furniture' 'apt_storage' 'apt_conditioner']
# --------------------------------------------------
# Колонка : col98
# Количество уникальных значений: 4
# Уникальные значения: ['apt_furniture' 'apt_kitchen' 'apt_storage' 'apt_conditioner']
# --------------------------------------------------
# Колонка : col99
# Количество уникальных значений: 6
# Уникальные значения: ['apt_kitchen' 'apt_furniture' 'apt_decor' 'apt_storage' 'apt_conditioner'
#  'apt_description']
# --------------------------------------------------
# Колонка : col100
# Количество уникальных значений: 6
# Уникальные значения: ['apt_kitchen' 'apt_furniture' 'apt_conditioner' 'apt_decor' 'apt_storage'
#  'apt_description']
# --------------------------------------------------
# Колонка : col129
# Количество уникальных значений: 9
# Уникальные значения: ['agents_panel' 'pervii_ekran' 'flat-detail-aside'
#  'other_mortgage_programs_list' 'main' 'offer_and_video3' 'mortgage_calc'
#  'main_banner' 'top_offer']
# --------------------------------------------------
# Колонка : col130
# Количество уникальных значений: 12
# Уникальные значения: ['pervii_ekran' 'flat-detail-aside' 'main_banner' 'offer_and_video3'
#  'agents_panel' 'online_mortgage' 'other_mortgage_programs_list'
#  'banner_ipoteka_mortgage-vtb-29' 'main' 'mortgage_calc' 'after_booking'
#  'top_offer']
# --------------------------------------------------
# Колонка : col131
# Количество уникальных значений: 13
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'main_banner' 'agents_panel'
#  'offer_and_video3' 'online_mortgage' 'other_mortgage_programs_list'
#  'contacts' 'banner_ipoteka_mortgage-vtb-29' 'main' 'mortgage_calc'
#  'top_offer' 'after_booking']
# --------------------------------------------------
# Колонка : col132
# Количество уникальных значений: 18
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'agents_panel' 'main_banner' 'main'
#  'offer_and_video3' 'online_mortgage' 'mortgage_calc' 'contacts'
#  'other_mortgage_programs_list' 'start_sale'
#  'banner_ipoteka_mortgage-vtb-29' 'top_offer' 'project_on_map'
#  'details-video' 'main_comm' 'compare' 'after_booking']
# --------------------------------------------------
# Колонка : col133
# Количество уникальных значений: 10
# Уникальные значения: ['flat-detail-aside' 'agents_panel' 'pervii_ekran'
#  'other_mortgage_programs_list' 'contacts' 'main' 'offer_and_video3'
#  'personal_area' 'main_banner' 'top_offer']
# --------------------------------------------------
# Колонка : col134
# Количество уникальных значений: 12
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'agents_panel' 'main_banner'
#  'after_booking' 'offer_and_video3' 'main' 'other_mortgage_programs_list'
#  'contacts' 'banner_ipoteka_mortgage-vtb-29' 'personal_area' 'top_offer']
# --------------------------------------------------
# Колонка : col135
# Количество уникальных значений: 15
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'agents_panel' 'main_banner'
#  'after_booking' 'offer_and_video3' 'main' 'other_mortgage_programs_list'
#  'contacts' 'banner_ipoteka_mortgage-vtb-29' 'mortgage_calc'
#  'online_mortgage' 'top_offer' 'make_appointment' 'personal_area']
# --------------------------------------------------
# Колонка : col136
# Количество уникальных значений: 20
# Уникальные значения: ['flat-detail-aside' 'agents_panel' 'contacts' 'pervii_ekran'
#  'main_banner' 'main' 'after_booking' 'mortgage_calc' 'offer_and_video3'
#  'other_mortgage_programs_list' 'online_mortgage' 'start_sale'
#  'banner_ipoteka_ipoteka-tranches' 'make_appointment' 'banner_ipoteka_2_9'
#  'personal_area' 'project_on_map' 'details-video' 'main_comm' 'top_offer']
# --------------------------------------------------
# Колонка : col137
# Количество уникальных значений: 3
# Уникальные значения: ['Ипотека 2.9' 'Ипотека' 'Ипотека 0,01']
# --------------------------------------------------
# Колонка : col138
# Количество уникальных значений: 4
# Уникальные значения: ['Ипотека' 'Ипотека 2.9' 'Ипотека 2,99' 'Ипотека 0,01']
# --------------------------------------------------
# Колонка : col139
# Количество уникальных значений: 4
# Уникальные значения: ['Ипотека' 'Ипотека 2.9' 'Ипотека 2,99' 'Ипотека 0,01']
# --------------------------------------------------
# Колонка : col140
# Количество уникальных значений: 6
# Уникальные значения: ['Ипотека' 'Ипотека 2.9' 'Ипотека 0,01' 'Ипотека 0.01' 'levelup'
#  'Ипотека 2,99']
# --------------------------------------------------
# Колонка : col141
# Количество уникальных значений: 3
# Уникальные значения: ['Ипотека 2.9' 'Ипотека' 'Ипотека 0,01']
# --------------------------------------------------
# Колонка : col142
# Количество уникальных значений: 5
# Уникальные значения: ['Ипотека 0.01' 'Ипотека' 'Ипотека 2.9' 'Ипотека 0,01' 'Ипотека 2,99']
# --------------------------------------------------
# Колонка : col143
# Количество уникальных значений: 5
# Уникальные значения: ['Ипотека' 'Ипотека 0.01' 'Ипотека 2.9' 'Ипотека 0,01' 'Ипотека 2,99']
# --------------------------------------------------
# Колонка : col144
# Количество уникальных значений: 8
# Уникальные значения: ['Ипотека 2.9' 'Ипотека' 'Ипотека 0.01' 'Ипотека 0,01' 'Ипотека_2_9'
#  'levelup' 'Ипотека траншами' 'Рассрочка от застройщика']
# --------------------------------------------------
# Колонка : col145
# Количество уникальных значений: 12
# Уникальные значения: ['ipoteka-29' 'fix_client' 'booking_storage' 'mortgage' 'booking'
#  'mortgage_parking' 'callback_parking' 'ipoteka_001'
#  'netting_program_selling' 'booking_parking' 'complaint' 'levelup']
# --------------------------------------------------
# Колонка : col146
# Количество уникальных значений: 17
# Уникальные значения: ['booking' 'mortgage' 'ipoteka-29' 'levelup' 'booking_storage'
#  'netting_program_selling' 'fix_client' 'bigday_2022' 'mortgage_lk'
#  'mortgage_parking' 'callback_parking' 'ipoteka_mortgage-vtb-29'
#  'ipoteka_001' 'booking_parking' 'netting_calc' 'complaint'
#  'callback_storage']
# --------------------------------------------------
# Колонка : col147
# Количество уникальных значений: 23
# Уникальные значения: ['booking' 'mortgage' 'assignment_of_claim' 'ipoteka-29' 'levelup'
#  'booking_storage' 'fix_client' 'netting_program_selling' 'bigday_2022'
#  'mortgage_lk' 'complaint' 'mortgage_parking' 'callback_parking'
#  'appointment' 'ipoteka_mortgage-vtb-29' 'ipoteka_001'
#  'meter_from_samolet' 'military' 'auction' 'excursion' 'booking_parking'
#  'netting_calc' 'callback_storage']
# --------------------------------------------------
# Колонка : col148
# Количество уникальных значений: 32
# Уникальные значения: ['booking' 'appointment' 'mortgage' 'fix_client' 'ipoteka-29'
#  'assignment_of_claim' 'levelup' 'ipoteka_001' 'callback_storage'
#  'consultation' 'booking_storage' 'netting_program_selling' 'mortgage_lk'
#  'auction' 'excursion' 'bigday_2022' 'netting_calc' 'complaint'
#  'meter_from_samolet' 'callback' 'mortgage_parking' 'consultation_house'
#  'callback_parking' 'evaluation' 'ipoteka_mortgage-vtb-29' 'military'
#  'netting' 'booking_parking' 'soon_projects_callback' 'installment_comm'
#  'project_card_consultation' 'samolet_bonus']
# --------------------------------------------------
# Колонка : col149
# Количество уникальных значений: 14
# Уникальные значения: ['booking' 'ipoteka-29' 'fix_client' 'booking_storage' 'mortgage'
#  'callback_parking' 'appointment' 'ipoteka_001' 'netting_program_selling'
#  'consultation' 'assignment_of_claim' 'booking_parking' 'complaint'
#  'levelup']
# --------------------------------------------------
# Колонка : col150
# Количество уникальных значений: 18
# Уникальные значения: ['booking' 'mortgage' 'ipoteka-29' 'levelup' 'fix_client'
#  'booking_storage' 'netting_program_selling' 'bigday_2022' 'ipoteka_001'
#  'booking_parking' 'callback_parking' 'appointment'
#  'ipoteka_mortgage-vtb-29' 'netting_calc' 'consultation'
#  'assignment_of_claim' 'complaint' 'callback_storage']
# --------------------------------------------------
# Колонка : col151
# Количество уникальных значений: 24
# Уникальные значения: ['booking' 'mortgage' 'assignment_of_claim' 'ipoteka-29' 'levelup'
#  'fix_client' 'booking_storage' 'netting_program_selling' 'bigday_2022'
#  'complaint' 'ipoteka_001' 'booking_parking' 'consultation_house'
#  'callback_parking' 'appointment' 'ipoteka_mortgage-vtb-29'
#  'samolet_bonus' 'mortgage_lk' 'meter_from_samolet' 'auction' 'excursion'
#  'netting_calc' 'consultation' 'callback_storage']
# --------------------------------------------------
# Колонка : col152
# Количество уникальных значений: 29
# Уникальные значения: ['booking_storage' 'booking' 'fix_client' 'mortgage' 'bigday_2022'
#  'assignment_of_claim' 'ipoteka-29' 'levelup' 'ipoteka_001'
#  'callback_storage' 'ipoteka_2_9' 'netting_program_selling' 'auction'
#  'appointment' 'netting_calc' 'complaint' 'meter_from_samolet' 'callback'
#  'booking_parking' 'consultation_house' 'callback_parking' 'evaluation'
#  'ipoteka-tranches' 'mortgage_lk' 'mortgage_parking' 'netting'
#  'consultation' 'soon_projects_callback' 'installment_comm']
# --------------------------------------------------
# Колонка : col153
# Количество уникальных значений: 7
# Уникальные значения: ['Спутник' 'Заречье Парк' 'Малая Охта' 'Новоданиловская 8'
#  'Живи! В Рыбацком' 'Астрид' 'Новое Колпино']
# --------------------------------------------------
# Колонка : col154
# Количество уникальных значений: 8
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Заречье Парк' 'Малая Охта'
#  'Новоданиловская 8' 'Астрид' 'Новое Колпино' 'Сандэй']
# --------------------------------------------------
# Колонка : col155
# Количество уникальных значений: 11
# Уникальные значения: ['Живи! В Рыбацком' 'Новоданиловская 8' 'Спутник' 'Заречье Парк'
#  'Малая Охта' 'Остафьево' 'Астрид' 'Тропарево Парк' 'Сандэй'
#  'Новое Колпино' 'Молжаниново']
# --------------------------------------------------
# Колонка : col156
# Количество уникальных значений: 17
# Уникальные значения: ['Верейская 41' 'Пятницкие Луга' 'Живи! В Рыбацком' 'Астрид' 'Спутник'
#  'Сандэй' 'Новоданиловская 8' 'Малая Охта' 'Заречье Парк' 'Остафьево'
#  'Тропарево Парк' 'Новое Внуково' 'Мытищи Парк' 'Пригород Лесное'
#  'Новое Колпино' 'Люберцы' 'Молжаниново']
# --------------------------------------------------
# Колонка : col157
# Количество уникальных значений: 8
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Заречье Парк' 'Малая Охта'
#  'Новоданиловская 8' 'Астрид' 'Новое Колпино' 'Сандэй']
# --------------------------------------------------
# Колонка : col158
# Количество уникальных значений: 9
# Уникальные значения: ['Сандэй' 'Спутник' 'Живи! В Рыбацком' 'Заречье Парк' 'Малая Охта'
#  'Новоданиловская 8' 'Верейская 41' 'Астрид' 'Новое Колпино']
# --------------------------------------------------
# Колонка : col159
# Количество уникальных значений: 14
# Уникальные значения: ['Живи! В Рыбацком' 'Сандэй' 'Спутник' 'Малая Охта' 'Алхимово'
#  'Новоданиловская 8' 'Астрид' 'Верейская 41' 'Заречье Парк' 'Молжаниново'
#  'Тропарево Парк' 'Мытищи Парк' 'Новое Колпино' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col160
# Количество уникальных значений: 20
# Уникальные значения: ['Новоданиловская 8' 'Живи! В Рыбацком' 'Сандэй' 'Верейская 41'
#  'Пятницкие Луга' 'Спутник' 'Малая Охта' 'Алхимово' 'Астрид'
#  'Заречье Парк' 'Остафьево' 'Молжаниново' 'Тропарево Парк' 'Мытищи Парк'
#  'Пригород Лесное' 'Новое Внуково' 'Большое Путилково' 'Новое Колпино'
#  'Люберцы' 'Рублевский Квартал']
# --------------------------------------------------
# Колонка : col161
# Количество уникальных значений: 4
# Уникальные значения: ['Параметры бронирования' 'Успешная оплата' 'Подтверждение брони'
#  'Подтверждение номера']
# --------------------------------------------------
# Колонка : col162
# Количество уникальных значений: 5
# Уникальные значения: ['Подтверждение номера' 'Успешная оплата' 'Подтверждение брони'
#  'Параметры бронирования' 'Данные покупателя']
# --------------------------------------------------
# Колонка : col163
# Количество уникальных значений: 7
# Уникальные значения: ['Успешная оплата' 'Подтверждение номера' 'Данные покупателя'
#  'Подтверждение брони' 'Параметры бронирования' 'Договор оферты'
#  'Информация об аукционе']
# --------------------------------------------------
# Колонка : col164
# Количество уникальных значений: 8
# Уникальные значения: ['Успешная оплата' 'Параметры бронирования' 'Подтверждение номера'
#  'Подтверждение брони' 'Данные покупателя' 'Информация об аукционе'
#  'Договор оферты' 'Возврат денег с сайта']
# --------------------------------------------------
# Колонка : col165
# Количество уникальных значений: 3
# Уникальные значения: ['Успешная оплата' 'Данные покупателя' 'Подтверждение номера']
# --------------------------------------------------
# Колонка : col166
# Количество уникальных значений: 5
# Уникальные значения: ['Успешная оплата' 'Подтверждение номера' 'Данные покупателя'
#  'Договор оферты' 'Подтверждение брони']
# --------------------------------------------------
# Колонка : col167
# Количество уникальных значений: 6
# Уникальные значения: ['Подтверждение номера' 'Успешная оплата' 'Данные покупателя'
#  'Договор оферты' 'Информация об аукционе' 'Подтверждение брони']
# --------------------------------------------------
# Колонка : col168
# Количество уникальных значений: 7
# Уникальные значения: ['Договор оферты' 'Подтверждение номера' 'Успешная оплата'
#  'Данные покупателя' 'Информация об аукционе' 'Параметры бронирования'
#  'Подтверждение брони']
# --------------------------------------------------
# Колонка : col169
# Количество уникальных значений: 1
# Уникальные значения: ['РЕН_Тренд']
# --------------------------------------------------
# Колонка : col170
# Количество уникальных значений: 6
# Уникальные значения: ['Юхоум' 'РЕН_Тренд' 'РЕН_Н-МАРКЕТ' 'ООО МФОУК Перспектива24'
#  'ООО «Илис групп»' 'RedCat']
# --------------------------------------------------
# Колонка : col171
# Количество уникальных значений: 9
# Уникальные значения: ['АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' 'Юхоум' 'РЕН_Тренд'
#  'TrendAgent' 'ООО МФОУК Перспектива24' 'РЕН_Н-МАРКЕТ'
#  'ИП Малявина Полина Викторовна' 'ООО «Илис групп»' 'RedCat']
# --------------------------------------------------
# Колонка : col172
# Количество уникальных значений: 18
# Уникальные значения: ['"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'РЕН_Тренд' 'АДВЕКС' 'АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' 'Юхоум'
#  'ООО МФОУК Перспектива24' 'ООО ЦНС' 'РЕН_Н-МАРКЕТ' 'TrendAgent'
#  'ИП Малявина Полина Викторовна' 'ООО «Илис групп»'
#  '"ООО ""Новостройки"" Мск"' 'Инхаус' 'РЕН_ЭТАЖИ' 'ООО «ЭТАЖИ»'
#  'ИП Лейман' 'RedCat' 'Перспектива 24 (федеральный)']
# --------------------------------------------------
# Колонка : col173
# Количество уникальных значений: 4
# Уникальные значения: ['РЕН_Тренд' 'TrendAgent' '"ООО ""Новостройки"" Мск"' 'PrilsGroup']
# --------------------------------------------------
# Колонка : col174
# Количество уникальных значений: 17
# Уникальные значения: ['Мегаполис-Сочи' 'АДВЕКС'
#  '"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'TrendAgent' 'РЕН_Тренд' 'Юхоум' 'РЕН_Н-МАРКЕТ' 'Бюро Новостроек'
#  'ООО МФОУК Перспектива24' '"ООО ""Новостройки"" Мск"'
#  'Союз Девелоперов Москвы' 'ИП Малявина Полина Викторовна' 'PrilsGroup'
#  'ООО «Вайтвилл»' 'ООО «Илис групп»' 'ИП Ободова Галина Вадимовна'
#  'RedCat']
# --------------------------------------------------
# Колонка : col175
# Количество уникальных значений: 26
# Уникальные значения: ['Мегаполис-Сочи' 'РЕН_Тренд' 'Инвестиционное агентство Волковой Татьяны'
#  'АДВЕКС' '"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'TrendAgent' 'ООО Элитная недвижимость'
#  'АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' '"ООО ""Новостройки"" Мск"'
#  'Юхоум' 'РЕН_ИТАКА' 'ООО МФОУК Перспектива24' 'ООО ЦНС'
#  '"ООО ""Молодострой"""' 'Военно-ипотечная компания'
#  'Перспектива 24 (федеральный)' 'ИП Малявина Полина Викторовна'
#  'Бюро Новостроек' 'Союз Девелоперов Москвы' 'РЕН_ЭТАЖИ' 'PrilsGroup'
#  'ООО «Вайтвилл»' 'ООО «Илис групп»' 'РЕН_Н-МАРКЕТ'
#  'ИП Ободова Галина Вадимовна' 'RedCat']
# --------------------------------------------------
# Колонка : col176
# Количество уникальных значений: 37
# Уникальные значения: ['Кипмоскоу' 'Азбука' 'Перспектива 24 (федеральный)' 'РЕН_Тренд'
#  '"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'Мегаполис-Сочи' 'TrendAgent' 'Инвестиционное агентство Волковой Татьяны'
#  'АДВЕКС' 'Союз Девелоперов Москвы' 'ООО МФОУК Перспектива24' 'ООО ЦНС'
#  'ООО Элитная недвижимость' 'ИП Ободова Галина Вадимовна'
#  'АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' '"ООО ""Новостройки"" Мск"'
#  'Юхоум' 'ООО Петербургские новостройки' 'РЕН_Н-МАРКЕТ' 'РЕН_ИТАКА'
#  'Военно-ипотечная компания' 'ЦАН' 'ИП Малявина Полина Викторовна'
#  'ООО «Илис групп»' 'Самолет плюс' '"ООО ""Молодострой"""'
#  '"ООО ""РФН Партнер"""' 'Инхаус' 'Бюро Новостроек' 'РЕН_ЭТАЖИ' 'RedCat'
#  'Крылатское' 'ООО «ЭТАЖИ»' 'ИП Лейман' 'PrilsGroup' 'ООО «Вайтвилл»'
#  'РЕН_ПАРТНЕР']
# --------------------------------------------------
# Колонка : col181
# Количество уникальных значений: 5
# Уникальные значения: ['Гостиная' 'Детская для мальчика' 'Ванная комната' 'Прихожая' 'Кухня']
# --------------------------------------------------
# Колонка : col182
# Количество уникальных значений: 7
# Уникальные значения: ['Ванная комната' 'Гостиная' 'Детская для мальчика' 'Спальня' 'Прихожая'
#  'Кухня' 'Детская для девочки']
# --------------------------------------------------
# Колонка : col183
# Количество уникальных значений: 8
# Уникальные значения: ['Кабинет' 'Ванная комната' 'Гостиная' 'Спальня' 'Кухня' 'Прихожая'
#  'Детская для мальчика' 'Детская для девочки']
# --------------------------------------------------
# Колонка : col184
# Количество уникальных значений: 8
# ...
# --------------------------------------------------
# Колонка : col1076
# Количество уникальных значений: 2
# Уникальные значения: ['press_family' 'it_mortgage']
# --------------------------------------------------
# Колонка : col1170
# Количество уникальных значений: 7
# Уникальные значения: ['2' '3' '10' '76' '17' '1' 'СП3МОЦ']
# --------------------------------------------------
# Колонка : col1171
# Количество уникальных значений: 7
# Уникальные значения: ['2' '3' '76' '10' '17' '1' 'СП3МОЦ']
# --------------------------------------------------
# Колонка : col1172
# Количество уникальных значений: 11
# Уникальные значения: ['2' '16' '17' '3' '76' '10' '1' '9' '31' 'М17' 'СП3МОЦ']
# --------------------------------------------------
# Колонка : col1174
# Количество уникальных значений: 4
# Уникальные значения: ['Спутник' 'Живи! В Рыбацком' 'Астрид' 'Малая Охта']
# --------------------------------------------------
# Колонка : col1175
# Количество уникальных значений: 4
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Астрид' 'Малая Охта']
# --------------------------------------------------
# Колонка : col1176
# Количество уникальных значений: 4
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Астрид' 'Малая Охта']
# --------------------------------------------------
# Колонка : col1177
# Количество уникальных значений: 3
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Астрид']
# --------------------------------------------------
# Колонка : col1178
# Количество уникальных значений: 5
# Уникальные значения: ['Спутник' 'Живи! В Рыбацком' 'Малая Охта' 'Астрид' 'Новоданиловская 8']
# --------------------------------------------------
# Колонка : col1179
# Количество уникальных значений: 5
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Астрид' 'Малая Охта' 'Новоданиловская 8']
# --------------------------------------------------
# Колонка : col1180
# Количество уникальных значений: 6
# Уникальные значения: ['Новоданиловская 8' 'Живи! В Рыбацком' 'Спутник' 'Астрид' 'Малая Охта'
#  'Сандэй']
# --------------------------------------------------
# Колонка : col1273
# Количество уникальных значений: 4
# Уникальные значения: ['СТИЛОБАТ1' '2.1' '36' '1']
# --------------------------------------------------
# Колонка : col1274
# Количество уникальных значений: 5
# Уникальные значения: ['СТИЛОБАТ1' '2.1' '10' '36' '1']
# --------------------------------------------------
# Колонка : col1275
# Количество уникальных значений: 5
# Уникальные значения: ['СТИЛОБАТ1' '2.1' '10' '36' '1']
# --------------------------------------------------
# Колонка : col1276
# Количество уникальных значений: 10
# Уникальные значения: ['СТИЛОБАТ1' '15' '14' '2.1' '66' '1' '10' '1.1' '32' '36']
# --------------------------------------------------
# Колонка : col1277
# Количество уникальных значений: 7
# Уникальные значения: ['3' '1' '14' 'СТИЛОБАТ1' '2.1' '36' '32']
# --------------------------------------------------
# Колонка : col1278
# Количество уникальных значений: 8
# Уникальные значения: ['3' '1' '14' 'СТИЛОБАТ1' '1.1' '2.1' '32' '36']
# --------------------------------------------------
# Колонка : col1279
# Количество уникальных значений: 11
# Уникальные значения: ['СТИЛОБАТ1' '1' '3' '10' '14' '1.1' '2.1' '32' 'СП3К14' '64' '36']
# --------------------------------------------------
# Колонка : col1280
# Количество уникальных значений: 20
# Уникальные значения: ['СТИЛОБАТ1' '1' '3' '15' '10' '2' '14' '2.1' '1.1' '13' '66' '2.2' '32'
#  '12.3' '12' '64' 'СП3К14' '36' '11' '1.2']
# --------------------------------------------------
# Колонка : col1445
# Количество уникальных значений: 4
# Уникальные значения: ['Живи! В Рыбацком' 'Пригород Лесное' 'Спутник' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col1446
# Количество уникальных значений: 7
# Уникальные значения: ['Спутник' 'Живи! В Рыбацком' 'Пригород Лесное' 'Новое Колпино' 'Астрид'
#  'Малая Охта' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col1447
# Количество уникальных значений: 9
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Малая Охта' 'Пригород Лесное'
#  'Новое Колпино' 'Астрид' 'Заречье Парк' 'Сандэй' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col1448
# Количество уникальных значений: 16
# Уникальные значения: ['Мытищи Парк' 'Живи! В Рыбацком' 'Спутник' 'Малая Охта' 'Остафьево'
#  'Новое Колпино' 'Пригород Лесное' 'Долина Яузы' 'Люберцы' 'Астрид'
#  'Новое Внуково' 'Сандэй' 'Новоданиловская 8' 'Заречье Парк'
#  'Верейская 41' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col1449
# Количество уникальных значений: 5
# Уникальные значения: ['Живи! В Рыбацком' 'Пригород Лесное' 'Спутник' 'Верейская 41'
#  'Большое Путилково']
# --------------------------------------------------
# Колонка : col1450
# Количество уникальных значений: 8
# Уникальные значения: ['Спутник' 'Живи! В Рыбацком' 'Пригород Лесное' 'Новое Колпино'
#  'Мытищи Парк' 'Малая Охта' 'Верейская 41' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col1451
# Количество уникальных значений: 11
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Малая Охта' 'Пригород Лесное'
#  'Новое Колпино' 'Мытищи Парк' 'Астрид' 'Заречье Парк' 'Верейская 41'
#  'Сандэй' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col1452
# Количество уникальных значений: 17
# Уникальные значения: ['Мытищи Парк' 'Живи! В Рыбацком' 'Спутник' 'Малая Охта' 'Новое Колпино'
#  'Остафьево' 'Астрид' 'Пригород Лесное' 'Долина Яузы' 'Люберцы' 'Алхимово'
#  'Новое Внуково' 'Сандэй' 'Верейская 41' 'Заречье Парк'
#  'Большое Путилково' 'Квартал Некрасовка']
# --------------------------------------------------
# Колонка : col1454
# Количество уникальных значений: 4817
# Уникальные значения: ['00f3d719-a6ec-4960-ba01-8372eb705443'
#  '01febac0-b083-494e-8589-f98400074b94'
#  '0278175e-c0bb-4e1e-bfe5-20db6811d3e2' ...
#  'eb4322a5-4650-ed11-b823-005056b825cd'
#  'f99a16a8-c0ef-ec11-b822-005056b8a6c4'
#  'fdf04fb7-5404-4a9c-ae5b-e1e893060631']
# --------------------------------------------------
# Колонка : col1647
# Количество уникальных значений: 2
# Уникальные значения: ['Тестовая бронь' 'Тестовая сделка']
# --------------------------------------------------
# Колонка : col1648
# Количество уникальных значений: 2
# Уникальные значения: ['Тестовая бронь' 'Тестовая сделка']
# --------------------------------------------------
# Колонка : col1649
# Количество уникальных значений: 6
# Уникальные значения: ['Тестовая бронь' 'Апартаменты' 'Не выходит на связь'
#  'Нет аккредитации по субсидии/ВИ/Банк' 'Тестовая сделка'
#  'Нет денег на ПВ']
# --------------------------------------------------
# Колонка : col1650
# Количество уникальных значений: 7
# Уникальные значения: ['Тестовая бронь' 'Апартаменты' 'Не выходит на связь'
#  'Нет аккредитации по субсидии/ВИ/Банк' 'Тестовая сделка'
#  'Нет денег на ПВ' 'Купил у конкурента (первичный рынок)']
# --------------------------------------------------
# Колонка : col1651
# Количество уникальных значений: 9
# Уникальные значения: ['Тестовая бронь' 'Ожидает поступление денежных средств' 'Не сообщил где'
#  'Апартаменты' 'Не выходит на связь'
#  'Нет аккредитации по субсидии/ВИ/Банк'
#  'Купил у конкурента (первичный рынок)' 'Тестовая сделка'
#  'Нет денег на ПВ']
# --------------------------------------------------
# Колонка : col1652
# Количество уникальных значений: 11
# Уникальные значения: ['Дубль заявки' 'Тестовая бронь' 'Ожидает поступление денежных средств'
#  'Не сообщил где' 'Апартаменты' 'Не выходит на связь'
#  'Нет аккредитации по субсидии/ВИ/Банк'
#  'Купил у конкурента (первичный рынок)' 'Тестовая сделка'
#  'Нет денег на ПВ' 'Продает квартиру']
# --------------------------------------------------
# Колонка : col1653
# Количество уникальных значений: 2
# Уникальные значения: ['Тестовая бронь' 'Тестовая сделка']
# --------------------------------------------------
# Колонка : col1654
# Количество уникальных значений: 11
# Уникальные значения: ['Дубль заявки' 'Тестовая бронь' 'Ожидает поступление денежных средств'
#  'Не сообщил где' 'Апартаменты' 'Не выходит на связь'
#  'Нет аккредитации по субсидии/ВИ/Банк'
#  'Купил у конкурента (первичный рынок)' 'Тестовая сделка'
#  'Нет денег на ПВ' 'Продает квартиру']
# --------------------------------------------------
# Колонка : col2191
# Количество уникальных значений: 7
# Уникальные значения: ['Замена квартиры' 'Продает квартиру' 'Не устроили условия'
#  'Отказы банков' 'Не оплатил опцион' 'Купил у конкурента (самолет)у'
#  'Отказ без объяснения причин']
# --------------------------------------------------
# Колонка : col2192
# Количество уникальных значений: 21
# Уникальные значения: ['Замена квартиры' 'Нет аккредитации по субсидии/ВИ/Банк'
#  'Не устроила оценка (Ievel up, ТИ, выкуп)'
#  'Изменение условий кредитования' 'Тестовая бронь' 'Не устроили условия'
#  'Политическая ситуация' 'Новая очередь/корпус' 'Отложил продажу'
#  'Отказы банков' 'Одобрена меньшая сумма' 'Истек срок опциона'
#  'Не оплатил опцион' 'Тестовая сделка' 'Замена ОН на < S' 'Дубль заявки'
#  'Не устроили условия реализации' 'Купил у конкурента (первичный рынок)'
#  'Купил у конкурента (самолет)у' 'Не продал квартиру/машину'
#  'Отказ без объяснения причин']
# --------------------------------------------------
# Колонка : col2193
# Количество уникальных значений: 33
# Уникальные значения: ['Замена квартиры' 'Нет аккредитации по субсидии/ВИ/Банк'
#  'Не устроила оценка (Ievel up, ТИ, выкуп)'
#  'Изменение условий кредитования' 'Не оплатил опцион'
#  'Необходимо посоветоваться с ЛПР' 'Квартира подорожала'
#  'Политическая ситуация' 'Отказы банков' 'Новая очередь/корпус'
#  'Замена ОН на > S' 'Ожидает поступление денежных средств'
#  'Ждет понижение цен на рынке' 'Отложил продажу' 'Тестовая бронь'
#  'Не продал квартиру/машину' 'Отказ без объяснения причин'
#  'Одобрена меньшая сумма' 'Нет нужного этажа' 'Рождение ребенка'
#  'Не могут определиться с планировочным решением' 'Истек срок опциона'
#  'Тестовая сделка' 'Замена ОН на < S' 'Дубль заявки' 'Создана ошибочно'
#  'Не устроили условия реализации' 'Купил у конкурента (первичный рынок)'
#  'Продает квартиру' 'Решил вложить деньги в другое' 'Нет денег на ПВ'
#  'Отказ Банков' 'Купил у конкурента (самолет)у']
# --------------------------------------------------
# Колонка : col2194
# Количество уникальных значений: 38
# Уникальные значения: ['Замена квартиры' 'Не нравится район'
#  'Нет аккредитации по субсидии/ВИ/Банк' 'Отказы банков'
#  'Не устроила оценка (Ievel up, ТИ, выкуп)'
#  'Изменение условий кредитования' 'Не оплатил опцион'
#  'Необходимо посоветоваться с ЛПР' 'Нет денег на ПВ' 'Квартира подорожала'
#  'Политическая ситуация' 'Нет нужной планировки' 'Новая очередь/корпус'
#  'Ждет понижение цен на рынке' 'Замена ОН на > S'
#  'Ожидает поступление денежных средств' 'Истек срок опциона'
#  'Не продал квартиру/машину' 'Отложил продажу' 'Дубль заявки'
#  'Купил у конкурента (первичный рынок)' 'Отказ без объяснения причин'
#  'Одобрена меньшая сумма' 'Тестовая бронь' 'Нет нужного этажа'
#  'Рождение ребенка' 'Не могут определиться с планировочным решением'
#  'Тестовая сделка' 'Замена ОН на < S' 'Нет согласия одного из супругов'
#  'Создана ошибочно' 'Не устроили условия реализации' 'Продает квартиру'
#  'Решил вложить деньги в другое' 'Замена покупателя' 'Ошибка при оплате'
#  'Отказ Банков' 'Купил у конкурента (самолет)у']
# --------------------------------------------------
# Колонка : col2195
# Количество уникальных значений: 45
# Уникальные значения: ['Истек срок опциона' 'Тестовая сделка' 'Не устроили условия реализации'
#  'Уехали жить за границу/в другой город' 'Решил вложить деньги в другое'
#  'Замена квартиры' 'Не нравится район' 'Отказы банков'
#  'Нет аккредитации по субсидии/ВИ/Банк' 'Продает квартиру'
#  'Отказ без объяснения причин' 'Не устроила оценка (Ievel up, ТИ, выкуп)'
#  'Изменение условий кредитования'
#  'Не подходят условия банка (ПВ, срок, ставка, страховка)'
#  'Не оплатил опцион' 'Необходимо посоветоваться с ЛПР'
#  'Квартира подорожала' 'Политическая ситуация' 'Нет нужной планировки'
#  'Новая очередь/корпус' 'Не продал квартиру/машину'
#  'Ждет понижение цен на рынке' 'Замена ОН на > S'
#  'Ожидает поступление денежных средств'
#  'Купил у конкурента (первичный рынок)' 'Дубль заявки' 'Отложил продажу'
#  'Одобрена меньшая сумма' 'Болезнь клиента' 'Тестовая бронь'
#  'Нет нужного этажа' 'Рождение ребенка'
#  'Не могут определиться с планировочным решением' 'Создана ошибочно'
#  'Замена ОН на < S' 'Плохая транспортная доступность'
#  'Купил у конкурента (самолет)у' 'Нет согласия одного из супругов'
#  'Пропала потребность в продаже' 'Иное' 'Увольнение с работы'
#  'Замена покупателя' 'Ошибка при оплате' 'Нет денег на ПВ' 'Отказ Банков']
# --------------------------------------------------
# Колонка : col2196
# Количество уникальных значений: 50
# Уникальные значения: ['Истек срок опциона' 'Продает квартиру' 'Тестовая сделка'
#  'Не устроили условия реализации' 'Уехали жить за границу/в другой город'
#  'Решил вложить деньги в другое' 'Замена квартиры' 'Не нравится район'
#  'Отказы банков' 'Нет аккредитации по субсидии/ВИ/Банк'
#  'Отказ без объяснения причин' 'Не устроила оценка (Ievel up, ТИ, выкуп)'
#  'Изменение условий кредитования'
#  'Не подходят условия банка (ПВ, срок, ставка, страховка)'
#  'Не оплатил опцион' 'Необходимо посоветоваться с ЛПР'
#  'Квартира подорожала' 'Политическая ситуация' 'Нет нужной планировки'
#  'Новая очередь/корпус' 'Не продал квартиру/машину'
#  'Ждет понижение цен на рынке' 'Дубль заявки' 'Замена ОН на > S'
#  'Ожидает поступление денежных средств' 'Увольнение с работы'
#  'Болезнь клиента' 'Купил у конкурента (первичный рынок)'
#  'Отложил продажу' 'Одобрена меньшая сумма' 'Тестовая бронь'
#  'Не выходит на связь' 'Купил в другом городе' 'Нет нужного этажа'
#  'Рождение ребенка' 'Не могут определиться с планировочным решением'
#  'Создана ошибочно' 'Замена ОН на < S' 'Плохая транспортная доступность'
#  'Купил у конкурента (самолет)у' 'Несчастный случай в семье'
#  'Нет согласия одного из супругов' 'Пропала потребность в продаже' 'Иное'
#  'Замена покупателя' 'Только начал поиск недвижимости' 'Ошибка при оплате'
#  'Возрастные ограничения по ипотеке' 'Нет денег на ПВ' 'Отказ Банков']
# --------------------------------------------------
# Колонка : col2197
# Количество уникальных значений: 17
# Уникальные значения: ['Замена квартиры' 'Нет аккредитации по субсидии/ВИ/Банк'
#  'Не устроила оценка (Ievel up, ТИ, выкуп)'
#  'Изменение условий кредитования' 'Тестовая бронь' 'Не устроили условия'
#  'Новая очередь/корпус' 'Отложил продажу' 'Отказы банков'
#  'Одобрена меньшая сумма' 'Истек срок опциона' 'Не оплатил опцион'
#  'Тестовая сделка' 'Дубль заявки' 'Не устроили условия реализации'
#  'Купил у конкурента (самолет)у' 'Отказ без объяснения причин']
# --------------------------------------------------
# Колонка : col2198
# Количество уникальных значений: 50
# Уникальные значения: ['Истек срок опциона' 'Продает квартиру' 'Тестовая сделка'
#  'Не устроили условия реализации' 'Уехали жить за границу/в другой город'
#  'Решил вложить деньги в другое' 'Замена квартиры' 'Не нравится район'
#  'Отказы банков' 'Нет аккредитации по субсидии/ВИ/Банк'
#  'Отказ без объяснения причин' 'Не устроила оценка (Ievel up, ТИ, выкуп)'
#  'Изменение условий кредитования'
#  'Не подходят условия банка (ПВ, срок, ставка, страховка)'
#  'Не оплатил опцион' 'Необходимо посоветоваться с ЛПР'
#  'Квартира подорожала' 'Политическая ситуация' 'Нет нужной планировки'
#  'Новая очередь/корпус' 'Не продал квартиру/машину'
#  'Ждет понижение цен на рынке' 'Дубль заявки' 'Замена ОН на > S'
#  'Ожидает поступление денежных средств' 'Увольнение с работы'
#  'Болезнь клиента' 'Купил у конкурента (первичный рынок)'
#  'Отложил продажу' 'Возрастные ограничения по ипотеке'
#  'Одобрена меньшая сумма' 'Тестовая бронь' 'Не выходит на связь'
#  'Купил в другом городе' 'Нет нужного этажа' 'Рождение ребенка'
#  'Не могут определиться с планировочным решением' 'Создана ошибочно'
#  'Замена ОН на < S' 'Плохая транспортная доступность'
#  'Купил у конкурента (самолет)у' 'Несчастный случай в семье'
#  'Нет согласия одного из супругов' 'Пропала потребность в продаже' 'Иное'
#  'Замена покупателя' 'Только начал поиск недвижимости' 'Ошибка при оплате'
#  'Нет денег на ПВ' 'Отказ Банков']
# --------------------------------------------------

# %%
for colum  in Data_Test_Object.columns:
    
    unique_values = Data_Train_Object[colum].dropna().unique()
    print(f"Колонка : {colum}")
    print(f"Количество уникальных значений: {len(unique_values)}")
    print(f"Уникальные значения: {unique_values}")
    print("-" * 50)
# Out:
# Колонка : report_date
# Количество уникальных значений: 25
# Уникальные значения: ['2022-11-01' '2022-05-01' '2022-09-01' '2022-08-01' '2023-02-01'
#  '2023-01-01' '2022-02-01' '2022-12-01' '2022-06-01' '2022-10-01'
#  '2021-08-01' '2021-05-01' '2022-04-01' '2022-03-01' '2022-07-01'
#  '2021-10-01' '2021-02-01' '2022-01-01' '2021-12-01' '2021-04-01'
#  '2021-06-01' '2021-11-01' '2021-07-01' '2021-09-01' '2021-03-01']
# --------------------------------------------------
# Колонка : col49
# Количество уникальных значений: 5
# Уникальные значения: ['https://samolet.ru/commercial/'
#  'https://samolet.ru/spb/?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet_yd_s_brand_spb_common_search_search_samolet_text_spb-lo_33~yzizmzuw|70577427&utm_term=%D1%81%D0%B0%D0%BC%D0%BE%D0%BB%D0%B5%D1%82&utm_content=38601006397_|cid|70577427|gid|4903321849|aid|12096120121|adp|no|pos|premium1|src|search_none|dvc|mobile|reg|2|text_otdelka&calltouch_tm=yd_c:70577427_gb:4903321849_ad:12096120121_ph:38601006397_st:search_pt:premium_p:1_s:none_dt:mobile_reg:2_ret:_apt:none&yadclid=95349662&yadordid=170577427&yclid=9024159213120651263'
#  'https://samolet.ru/'
#  'https://samolet.ru/?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet_live_yd_s_brand_samoletgroup_search_search_samolet_text_mmo_33~mzywztjh|68613244&utm_term=%D0%B3%D0%BA%20%D1%81%D0%B0%D0%BC%D0%BE%D0%BB%D0%B5%D1%82&utm_content=35325882672_|cid|68613244|gid|4767846383|aid|11492307715|adp|no|pos|premium1|src|search_none|dvc|mobile|reg|213|text_top&calltouch_tm=yd_c:68613244_gb:4767846383_ad:11492307715_ph:35325882672_st:search_pt:premium_p:1_s:none_dt:mobile_reg:213_ret:_apt:none&_openstat=ZGlyZWN0LnlhbmRleC5ydTs2ODYxMzI0NDsxMTQ5MjMwNzcxNTt5YW5kZXgucnU6cHJlbWl1bQ&yclid=9519726883194274000&business_class=1'
#  'https://samolet.ru/project/']
# --------------------------------------------------
# Колонка : col50
# Количество уникальных значений: 8
# Уникальные значения: ['https://samolet.ru/?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet_live_yd_s_brand_samoletgroup_search_search_samolet_text_mmo_33~mzywztjh|68613244&utm_term=%D0%B6%D0%BA%20%D1%81%D0%B0%D0%BC%D0%BE%D0%BB%D0%B5%D1%82&utm_content=37376054825_|cid|68613244|gid|4767846385|aid|11502931156|adp|no|pos|premium1|src|search_none|dvc|mobile|reg|213|text_cena&calltouch_tm=yd_c:68613244_gb:4767846385_ad:11502931156_ph:37376054825_st:search_pt:premium_p:1_s:none_dt:mobile_reg:213_ret:_apt:none&yadclid=95349619&yadordid=168613244&yclid=18130280909992361983'
#  'https://samolet.ru/project/?business_class=1'
#  'https://samolet.ru/commercial/' 'https://samolet.ru/'
#  'https://samolet.ru/spb/?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet
# Количество уникальных значений: 3
# Уникальные значения: ['comm-main' 'main' 'projects_page']
# --------------------------------------------------
# Колонка : col62
# Количество уникальных значений: 3
# Уникальные значения: ['main' 'projects_page' 'comm-main']
# --------------------------------------------------
# Колонка : col63
# Количество уникальных значений: 3
# Уникальные значения: ['main' 'projects_page' 'comm-main']
# --------------------------------------------------
# Колонка : col64
# Количество уникальных значений: 3
# Уникальные значения: ['projects_page' 'main' 'comm-main']
# --------------------------------------------------
# Колонка : col85
# Количество уникальных значений: 2
# Уникальные значения: ['off' 'on']
# --------------------------------------------------
# Колонка : col86
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col87
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col88
# Количество уникальных значений: 2
# Уникальные значения: ['off' 'on']
# --------------------------------------------------
# Колонка : col89
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col90
# Количество уникальных значений: 2
# Уникальные значения: ['off' 'on']
# --------------------------------------------------
# Колонка : col91
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col92
# Количество уникальных значений: 2
# Уникальные значения: ['on' 'off']
# --------------------------------------------------
# Колонка : col93
# Количество уникальных значений: 3
# Уникальные значения: ['apt_kitchen' 'apt_storage' 'apt_furniture']
# --------------------------------------------------
# Колонка : col94
# Количество уникальных значений: 4
# Уникальные значения: ['apt_furniture' 'apt_kitchen' 'apt_storage' 'apt_decor']
# --------------------------------------------------
# Колонка : col95
# Количество уникальных значений: 5
# Уникальные значения: ['apt_furniture' 'apt_conditioner' 'apt_kitchen' 'apt_storage' 'apt_decor']
# --------------------------------------------------
# Колонка : col96
# Количество уникальных значений: 6
# Уникальные значения: ['apt_furniture' 'apt_kitchen' 'apt_conditioner' 'apt_storage' 'apt_decor'
#  'apt_description']
# --------------------------------------------------
# Колонка : col97
# Количество уникальных значений: 4
# Уникальные значения: ['apt_kitchen' 'apt_furniture' 'apt_storage' 'apt_conditioner']
# --------------------------------------------------
# Колонка : col98
# Количество уникальных значений: 4
# Уникальные значения: ['apt_furniture' 'apt_kitchen' 'apt_storage' 'apt_conditioner']
# --------------------------------------------------
# Колонка : col99
# Количество уникальных значений: 6
# Уникальные значения: ['apt_kitchen' 'apt_furniture' 'apt_decor' 'apt_storage' 'apt_conditioner'
#  'apt_description']
# --------------------------------------------------
# Колонка : col100
# Количество уникальных значений: 6
# Уникальные значения: ['apt_kitchen' 'apt_furniture' 'apt_conditioner' 'apt_decor' 'apt_storage'
#  'apt_description']
# --------------------------------------------------
# Колонка : col129
# Количество уникальных значений: 9
# Уникальные значения: ['agents_panel' 'pervii_ekran' 'flat-detail-aside'
#  'other_mortgage_programs_list' 'main' 'offer_and_video3' 'mortgage_calc'
#  'main_banner' 'top_offer']
# --------------------------------------------------
# Колонка : col130
# Количество уникальных значений: 12
# Уникальные значения: ['pervii_ekran' 'flat-detail-aside' 'main_banner' 'offer_and_video3'
#  'agents_panel' 'online_mortgage' 'other_mortgage_programs_list'
#  'banner_ipoteka_mortgage-vtb-29' 'main' 'mortgage_calc' 'after_booking'
#  'top_offer']
# --------------------------------------------------
# Колонка : col131
# Количество уникальных значений: 13
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'main_banner' 'agents_panel'
#  'offer_and_video3' 'online_mortgage' 'other_mortgage_programs_list'
#  'contacts' 'banner_ipoteka_mortgage-vtb-29' 'main' 'mortgage_calc'
#  'top_offer' 'after_booking']
# --------------------------------------------------
# Колонка : col132
# Количество уникальных значений: 18
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'agents_panel' 'main_banner' 'main'
#  'offer_and_video3' 'online_mortgage' 'mortgage_calc' 'contacts'
#  'other_mortgage_programs_list' 'start_sale'
#  'banner_ipoteka_mortgage-vtb-29' 'top_offer' 'project_on_map'
#  'details-video' 'main_comm' 'compare' 'after_booking']
# --------------------------------------------------
# Колонка : col133
# Количество уникальных значений: 10
# Уникальные значения: ['flat-detail-aside' 'agents_panel' 'pervii_ekran'
#  'other_mortgage_programs_list' 'contacts' 'main' 'offer_and_video3'
#  'personal_area' 'main_banner' 'top_offer']
# --------------------------------------------------
# Колонка : col134
# Количество уникальных значений: 12
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'agents_panel' 'main_banner'
#  'after_booking' 'offer_and_video3' 'main' 'other_mortgage_programs_list'
#  'contacts' 'banner_ipoteka_mortgage-vtb-29' 'personal_area' 'top_offer']
# --------------------------------------------------
# Колонка : col135
# Количество уникальных значений: 15
# Уникальные значения: ['flat-detail-aside' 'pervii_ekran' 'agents_panel' 'main_banner'
#  'after_booking' 'offer_and_video3' 'main' 'other_mortgage_programs_list'
#  'contacts' 'banner_ipoteka_mortgage-vtb-29' 'mortgage_calc'
#  'online_mortgage' 'top_offer' 'make_appointment' 'personal_area']
# --------------------------------------------------
# Колонка : col136
# Количество уникальных значений: 20
# Уникальные значения: ['flat-detail-aside' 'agents_panel' 'contacts' 'pervii_ekran'
#  'main_banner' 'main' 'after_booking' 'mortgage_calc' 'offer_and_video3'
#  'other_mortgage_programs_list' 'online_mortgage' 'start_sale'
#  'banner_ipoteka_ipoteka-tranches' 'make_appointment' 'banner_ipoteka_2_9'
#  'personal_area' 'project_on_map' 'details-video' 'main_comm' 'top_offer']
# --------------------------------------------------
# Колонка : col138
# Количество уникальных значений: 4
# Уникальные значения: ['Ипотека' 'Ипотека 2.9' 'Ипотека 2,99' 'Ипотека 0,01']
# --------------------------------------------------
# Колонка : col139
# Количество уникальных значений: 4
# Уникальные значения: ['Ипотека' 'Ипотека 2.9' 'Ипотека 2,99' 'Ипотека 0,01']
# --------------------------------------------------
# Колонка : col140
# Количество уникальных значений: 6
# Уникальные значения: ['Ипотека' 'Ипотека 2.9' 'Ипотека 0,01' 'Ипотека 0.01' 'levelup'
#  'Ипотека 2,99']
# --------------------------------------------------
# Колонка : col142
# Количество уникальных значений: 5
# Уникальные значения: ['Ипотека 0.01' 'Ипотека' 'Ипотека 2.9' 'Ипотека 0,01' 'Ипотека 2,99']
# --------------------------------------------------
# Колонка : col143
# Количество уникальных значений: 5
# Уникальные значения: ['Ипотека' 'Ипотека 0.01' 'Ипотека 2.9' 'Ипотека 0,01' 'Ипотека 2,99']
# --------------------------------------------------
# Колонка : col144
# Количество уникальных значений: 8
# Уникальные значения: ['Ипотека 2.9' 'Ипотека' 'Ипотека 0.01' 'Ипотека 0,01' 'Ипотека_2_9'
#  'levelup' 'Ипотека траншами' 'Рассрочка от застройщика']
# --------------------------------------------------
# Колонка : col145
# Количество уникальных значений: 12
# Уникальные значения: ['ipoteka-29' 'fix_client' 'booking_storage' 'mortgage' 'booking'
#  'mortgage_parking' 'callback_parking' 'ipoteka_001'
#  'netting_program_selling' 'booking_parking' 'complaint' 'levelup']
# --------------------------------------------------
# Колонка : col146
# Количество уникальных значений: 17
# Уникальные значения: ['booking' 'mortgage' 'ipoteka-29' 'levelup' 'booking_storage'
#  'netting_program_selling' 'fix_client' 'bigday_2022' 'mortgage_lk'
#  'mortgage_parking' 'callback_parking' 'ipoteka_mortgage-vtb-29'
#  'ipoteka_001' 'booking_parking' 'netting_calc' 'complaint'
#  'callback_storage']
# --------------------------------------------------
# Колонка : col147
# Количество уникальных значений: 23
# Уникальные значения: ['booking' 'mortgage' 'assignment_of_claim' 'ipoteka-29' 'levelup'
#  'booking_storage' 'fix_client' 'netting_program_selling' 'bigday_2022'
#  'mortgage_lk' 'complaint' 'mortgage_parking' 'callback_parking'
#  'appointment' 'ipoteka_mortgage-vtb-29' 'ipoteka_001'
#  'meter_from_samolet' 'military' 'auction' 'excursion' 'booking_parking'
#  'netting_calc' 'callback_storage']
# --------------------------------------------------
# Колонка : col148
# Количество уникальных значений: 32
# Уникальные значения: ['booking' 'appointment' 'mortgage' 'fix_client' 'ipoteka-29'
#  'assignment_of_claim' 'levelup' 'ipoteka_001' 'callback_storage'
#  'consultation' 'booking_storage' 'netting_program_selling' 'mortgage_lk'
#  'auction' 'excursion' 'bigday_2022' 'netting_calc' 'complaint'
#  'meter_from_samolet' 'callback' 'mortgage_parking' 'consultation_house'
#  'callback_parking' 'evaluation' 'ipoteka_mortgage-vtb-29' 'military'
#  'netting' 'booking_parking' 'soon_projects_callback' 'installment_comm'
#  'project_card_consultation' 'samolet_bonus']
# --------------------------------------------------
# Колонка : col149
# Количество уникальных значений: 14
# Уникальные значения: ['booking' 'ipoteka-29' 'fix_client' 'booking_storage' 'mortgage'
#  'callback_parking' 'appointment' 'ipoteka_001' 'netting_program_selling'
#  'consultation' 'assignment_of_claim' 'booking_parking' 'complaint'
#  'levelup']
# --------------------------------------------------
# Колонка : col150
# Количество уникальных значений: 18
# Уникальные значения: ['booking' 'mortgage' 'ipoteka-29' 'levelup' 'fix_client'
#  'booking_storage' 'netting_program_selling' 'bigday_2022' 'ipoteka_001'
#  'booking_parking' 'callback_parking' 'appointment'
#  'ipoteka_mortgage-vtb-29' 'netting_calc' 'consultation'
#  'assignment_of_claim' 'complaint' 'callback_storage']
# --------------------------------------------------
# Колонка : col151
# Количество уникальных значений: 24
# Уникальные значения: ['booking' 'mortgage' 'assignment_of_claim' 'ipoteka-29' 'levelup'
#  'fix_client' 'booking_storage' 'netting_program_selling' 'bigday_2022'
#  'complaint' 'ipoteka_001' 'booking_parking' 'consultation_house'
#  'callback_parking' 'appointment' 'ipoteka_mortgage-vtb-29'
#  'samolet_bonus' 'mortgage_lk' 'meter_from_samolet' 'auction' 'excursion'
#  'netting_calc' 'consultation' 'callback_storage']
# --------------------------------------------------
# Колонка : col152
# Количество уникальных значений: 29
# Уникальные значения: ['booking_storage' 'booking' 'fix_client' 'mortgage' 'bigday_2022'
#  'assignment_of_claim' 'ipoteka-29' 'levelup' 'ipoteka_001'
#  'callback_storage' 'ipoteka_2_9' 'netting_program_selling' 'auction'
#  'appointment' 'netting_calc' 'complaint' 'meter_from_samolet' 'callback'
#  'booking_parking' 'consultation_house' 'callback_parking' 'evaluation'
#  'ipoteka-tranches' 'mortgage_lk' 'mortgage_parking' 'netting'
#  'consultation' 'soon_projects_callback' 'installment_comm']
# --------------------------------------------------
# Колонка : col153
# Количество уникальных значений: 7
# Уникальные значения: ['Спутник' 'Заречье Парк' 'Малая Охта' 'Новоданиловская 8'
#  'Живи! В Рыбацком' 'Астрид' 'Новое Колпино']
# --------------------------------------------------
# Колонка : col154
# Количество уникальных значений: 8
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Заречье Парк' 'Малая Охта'
#  'Новоданиловская 8' 'Астрид' 'Новое Колпино' 'Сандэй']
# --------------------------------------------------
# Колонка : col155
# Количество уникальных значений: 11
# Уникальные значения: ['Живи! В Рыбацком' 'Новоданиловская 8' 'Спутник' 'Заречье Парк'
#  'Малая Охта' 'Остафьево' 'Астрид' 'Тропарево Парк' 'Сандэй'
#  'Новое Колпино' 'Молжаниново']
# --------------------------------------------------
# Колонка : col156
# Количество уникальных значений: 17
# Уникальные значения: ['Верейская 41' 'Пятницкие Луга' 'Живи! В Рыбацком' 'Астрид' 'Спутник'
#  'Сандэй' 'Новоданиловская 8' 'Малая Охта' 'Заречье Парк' 'Остафьево'
#  'Тропарево Парк' 'Новое Внуково' 'Мытищи Парк' 'Пригород Лесное'
#  'Новое Колпино' 'Люберцы' 'Молжаниново']
# --------------------------------------------------
# Колонка : col157
# Количество уникальных значений: 8
# Уникальные значения: ['Живи! В Рыбацком' 'Спутник' 'Заречье Парк' 'Малая Охта'
#  'Новоданиловская 8' 'Астрид' 'Новое Колпино' 'Сандэй']
# --------------------------------------------------
# Колонка : col158
# Количество уникальных значений: 9
# Уникальные значения: ['Сандэй' 'Спутник' 'Живи! В Рыбацком' 'Заречье Парк' 'Малая Охта'
#  'Новоданиловская 8' 'Верейская 41' 'Астрид' 'Новое Колпино']
# --------------------------------------------------
# Колонка : col159
# Количество уникальных значений: 14
# Уникальные значения: ['Живи! В Рыбацком' 'Сандэй' 'Спутник' 'Малая Охта' 'Алхимово'
#  'Новоданиловская 8' 'Астрид' 'Верейская 41' 'Заречье Парк' 'Молжаниново'
#  'Тропарево Парк' 'Мытищи Парк' 'Новое Колпино' 'Большое Путилково']
# --------------------------------------------------
# Колонка : col160
# Количество уникальных значений: 20
# Уникальные значения: ['Новоданиловская 8' 'Живи! В Рыбацком' 'Сандэй' 'Верейская 41'
#  'Пятницкие Луга' 'Спутник' 'Малая Охта' 'Алхимово' 'Астрид'
#  'Заречье Парк' 'Остафьево' 'Молжаниново' 'Тропарево Парк' 'Мытищи Парк'
#  'Пригород Лесное' 'Новое Внуково' 'Большое Путилково' 'Новое Колпино'
#  'Люберцы' 'Рублевский Квартал']
# --------------------------------------------------
# Колонка : col161
# Количество уникальных значений: 4
# Уникальные значения: ['Параметры бронирования' 'Успешная оплата' 'Подтверждение брони'
#  'Подтверждение номера']
# --------------------------------------------------
# Колонка : col162
# Количество уникальных значений: 5
# Уникальные значения: ['Подтверждение номера' 'Успешная оплата' 'Подтверждение брони'
#  'Параметры бронирования' 'Данные покупателя']
# --------------------------------------------------
# Колонка : col163
# Количество уникальных значений: 7
# Уникальные значения: ['Успешная оплата' 'Подтверждение номера' 'Данные покупателя'
#  'Подтверждение брони' 'Параметры бронирования' 'Договор оферты'
#  'Информация об аукционе']
# --------------------------------------------------
# Колонка : col164
# Количество уникальных значений: 8
# Уникальные значения: ['Успешная оплата' 'Параметры бронирования' 'Подтверждение номера'
#  'Подтверждение брони' 'Данные покупателя' 'Информация об аукционе'
#  'Договор оферты' 'Возврат денег с сайта']
# --------------------------------------------------
# Колонка : col165
# Количество уникальных значений: 3
# Уникальные значения: ['Успешная оплата' 'Данные покупателя' 'Подтверждение номера']
# --------------------------------------------------
# Колонка : col166
# Количество уникальных значений: 5
# Уникальные значения: ['Успешная оплата' 'Подтверждение номера' 'Данные покупателя'
#  'Договор оферты' 'Подтверждение брони']
# --------------------------------------------------
# Колонка : col167
# Количество уникальных значений: 6
# Уникальные значения: ['Подтверждение номера' 'Успешная оплата' 'Данные покупателя'
#  'Договор оферты' 'Информация об аукционе' 'Подтверждение брони']
# --------------------------------------------------
# Колонка : col168
# Количество уникальных значений: 7
# Уникальные значения: ['Договор оферты' 'Подтверждение номера' 'Успешная оплата'
#  'Данные покупателя' 'Информация об аукционе' 'Параметры бронирования'
#  'Подтверждение брони']
# --------------------------------------------------
# Колонка : col170
# Количество уникальных значений: 6
# Уникальные значения: ['Юхоум' 'РЕН_Тренд' 'РЕН_Н-МАРКЕТ' 'ООО МФОУК Перспектива24'
#  'ООО «Илис групп»' 'RedCat']
# --------------------------------------------------
# Колонка : col171
# Количество уникальных значений: 9
# Уникальные значения: ['АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' 'Юхоум' 'РЕН_Тренд'
#  'TrendAgent' 'ООО МФОУК Перспектива24' 'РЕН_Н-МАРКЕТ'
#  'ИП Малявина Полина Викторовна' 'ООО «Илис групп»' 'RedCat']
# --------------------------------------------------
# Колонка : col172
# Количество уникальных значений: 18
# Уникальные значения: ['"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'РЕН_Тренд' 'АДВЕКС' 'АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' 'Юхоум'
#  'ООО МФОУК Перспектива24' 'ООО ЦНС' 'РЕН_Н-МАРКЕТ' 'TrendAgent'
#  'ИП Малявина Полина Викторовна' 'ООО «Илис групп»'
#  '"ООО ""Новостройки"" Мск"' 'Инхаус' 'РЕН_ЭТАЖИ' 'ООО «ЭТАЖИ»'
#  'ИП Лейман' 'RedCat' 'Перспектива 24 (федеральный)']
# --------------------------------------------------
# Колонка : col173
# Количество уникальных значений: 4
# Уникальные значения: ['РЕН_Тренд' 'TrendAgent' '"ООО ""Новостройки"" Мск"' 'PrilsGroup']
# --------------------------------------------------
# Колонка : col174
# Количество уникальных значений: 17
# Уникальные значения: ['Мегаполис-Сочи' 'АДВЕКС'
#  '"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'TrendAgent' 'РЕН_Тренд' 'Юхоум' 'РЕН_Н-МАРКЕТ' 'Бюро Новостроек'
#  'ООО МФОУК Перспектива24' '"ООО ""Новостройки"" Мск"'
#  'Союз Девелоперов Москвы' 'ИП Малявина Полина Викторовна' 'PrilsGroup'
#  'ООО «Вайтвилл»' 'ООО «Илис групп»' 'ИП Ободова Галина Вадимовна'
#  'RedCat']
# --------------------------------------------------
# Колонка : col175
# Количество уникальных значений: 26
# Уникальные значения: ['Мегаполис-Сочи' 'РЕН_Тренд' 'Инвестиционное агентство Волковой Татьяны'
#  'АДВЕКС' '"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'TrendAgent' 'ООО Элитная недвижимость'
#  'АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' '"ООО ""Новостройки"" Мск"'
#  'Юхоум' 'РЕН_ИТАКА' 'ООО МФОУК Перспектива24' 'ООО ЦНС'
#  '"ООО ""Молодострой"""' 'Военно-ипотечная компания'
#  'Перспектива 24 (федеральный)' 'ИП Малявина Полина Викторовна'
#  'Бюро Новостроек' 'Союз Девелоперов Москвы' 'РЕН_ЭТАЖИ' 'PrilsGroup'
#  'ООО «Вайтвилл»' 'ООО «Илис групп»' 'РЕН_Н-МАРКЕТ'
#  'ИП Ободова Галина Вадимовна' 'RedCat']
# --------------------------------------------------
# Колонка : col176
# Количество уникальных значений: 37
# Уникальные значения: ['Кипмоскоу' 'Азбука' 'Перспектива 24 (федеральный)' 'РЕН_Тренд'
#  '"ООО ""Центр Развития Проектов"" Петербургская Недвижимость"""'
#  'Мегаполис-Сочи' 'TrendAgent' 'Инвестиционное агентство Волковой Татьяны'
#  'АДВЕКС' 'Союз Девелоперов Москвы' 'ООО МФОУК Перспектива24' 'ООО ЦНС'
#  'ООО Элитная недвижимость' 'ИП Ободова Галина Вадимовна'
#  'АГЕНТСТВО НЕДВИЖИМОСТИ МАРИИ ТАРАСОВОЙ' '"ООО ""Новостройки"" Мск"'
#  'Юхоум' 'ООО Петербургские новостройки' 'РЕН_Н-МАРКЕТ' 'РЕН_ИТАКА'
#  'Военно-ипотечная компания' 'ЦАН' 'ИП Малявина Полина Викторовна'
#  'ООО «Илис групп»' 'Самолет плюс' '"ООО ""Молодострой"""'
#  '"ООО ""РФН Партнер"""' 'Инхаус' 'Бюро Новостроек' 'РЕН_ЭТАЖИ' 'RedCat'
#  'Крылатское' 'ООО «ЭТАЖИ»' 'ИП Лейман' 'PrilsGroup' 'ООО «Вайтвилл»'
#  'РЕН_ПАРТНЕР']
# --------------------------------------------------
# Колонка : col181
# Количество уникальных значений: 5
# Уникальные значения: ['Гостиная' 'Детская для мальчика' 'Ванная комната' 'Прихожая' 'Кухня']
# --------------------------------------------------
# Колонка : col182
# Количество уникальных значений: 7
# Уникальные значения: ['Ванная комната' 'Гостиная' 'Детская для мальчика' 'Спальня' 'Прихожая'
#  'Кухня' 'Детская для девочки']
# --------------------------------------------------
# Колонка : col183
# Количество уникальных значений: 8
# Уникальные значения: ['Кабинет' 'Ванная комната' 'Гостиная' 'Спальня' 'Кухня' 'Прихожая'
#  'Детская для мальчика' 'Детская для девочки']
# --------------------------------------------------
# Колонка : col184
# Количество уникальных значений: 8
# Уникальные значения: ['Кухня' 'Кабинет' 'Спальня' 'Прихожая' 'Ванная комната' 'Гостиная'
#  'Детская для девочки' 'Детская для мальчика']
# --------------------------------------------------
# Колонка : col185
# Количество уникальных значений: 8
# Уникальные значения: ['Прихожая' 'Ванная комната' 'Детская для мальчика' 'Спальня' 'Кухня'
#  'Гостиная' 'Кабинет' 'Детская для девочки']
# --------------------------------------------------
# Колонка : col186
# Количество уникальных значений: 8
# ...
#  'a2d8abff-78b8-e611-80bf-005056b8d207'
#  'a03b7e8f-941c-e811-80dd-005056b8d207'
#  'a43b7e8f-941c-e811-80dd-005056b8d207'
#  'fab35ba8-af78-ec11-8121-005056b8d207'
#  'dfad20e9-8c4b-e711-80c5-005056b8d207'
#  'a23b7e8f-941c-e811-80dd-005056b8d207'
#  '92d863a3-1665-ea11-80f7-005056b8d207'
#  '56698c9e-35dd-ea11-80fc-005056b8d207']
# --------------------------------------------------
# Колонка : col1042
# Количество уникальных значений: 14
# Уникальные значения: ['9c3b7e8f-941c-e811-80dd-005056b8d207'
#  'a03b7e8f-941c-e811-80dd-005056b8d207'
#  'a2d8abff-78b8-e611-80bf-005056b8d207'
#  'a43b7e8f-941c-e811-80dd-005056b8d207'
#  'fde60ee3-11aa-e811-80de-005056b8d207'
#  '983b7e8f-941c-e811-80dd-005056b8d207'
#  '6da279e4-2805-ea11-80ed-005056b8d207'
#  '92d863a3-1665-ea11-80f7-005056b8d207'
#  'fab35ba8-af78-ec11-8121-005056b8d207'
#  'dfad20e9-8c4b-e711-80c5-005056b8d207'
#  'a23b7e8f-941c-e811-80dd-005056b8d207'
#  '56698c9e-35dd-ea11-80fc-005056b8d207'
#  '3f7995b6-cb53-eb11-810b-005056b8d207'
#  '2c30ab69-847a-eb11-8110-005056b8d207']
# --------------------------------------------------
# Колонка : col1043
# Количество уникальных значений: 18
# Уникальные значения: ['fab35ba8-af78-ec11-8121-005056b8d207'
#  '9c3b7e8f-941c-e811-80dd-005056b8d207'
#  'a2d8abff-78b8-e611-80bf-005056b8d207'
#  'a43b7e8f-941c-e811-80dd-005056b8d207'
#  'a03b7e8f-941c-e811-80dd-005056b8d207'
#  'fde60ee3-11aa-e811-80de-005056b8d207'
#  'a23b7e8f-941c-e811-80dd-005056b8d207'
#  '983b7e8f-941c-e811-80dd-005056b8d207'
#  '92d863a3-1665-ea11-80f7-005056b8d207'
#  '6da279e4-2805-ea11-80ed-005056b8d207'
#  'e48f6c85-7414-e711-80c1-005056b8d207'
#  '97a6d484-1665-ea11-80f7-005056b8d207'
#  '3700ca2a-35dd-ea11-80fc-005056b8d207'
#  'dfad20e9-8c4b-e711-80c5-005056b8d207'
#  'deb76297-1665-ea11-80f7-005056b8d207'
#  '56698c9e-35dd-ea11-80fc-005056b8d207'
#  '3f7995b6-cb53-eb11-810b-005056b8d207'
#  '2c30ab69-847a-eb11-8110-005056b8d207']
# --------------------------------------------------
# Колонка : col1044
# Количество уникальных значений: 22
# Уникальные значения: ['fab35ba8-af78-ec11-8121-005056b8d207'
#  '3f7995b6-cb53-eb11-810b-005056b8d207'
#  'e34c4077-7127-e811-80dd-005056b8d207'
#  '9c3b7e8f-941c-e811-80dd-005056b8d207'
#  'a2d8abff-78b8-e611-80bf-005056b8d207'
#  'a43b7e8f-941c-e811-80dd-005056b8d207'
#  '983b7e8f-941c-e811-80dd-005056b8d207'
#  'a03b7e8f-941c-e811-80dd-005056b8d207'
#  '92d863a3-1665-ea11-80f7-005056b8d207'
#  'a23b7e8f-941c-e811-80dd-005056b8d207'
#  'fde60ee3-11aa-e811-80de-005056b8d207'
#  'c15cec57-3b3e-ed11-b826-005056b81dee'
#  '6da279e4-2805-ea11-80ed-005056b8d207'
#  '97a6d484-1665-ea11-80f7-005056b8d207'
#  '07091659-2705-e911-80e5-005056b8d207'
#  'dfad20e9-8c4b-e711-80c5-005056b8d207'
#  '3700ca2a-35dd-ea11-80fc-005056b8d207'
#  '3b7995b6-cb53-eb11-810b-005056b8d207'
#  'deb76297-1665-ea11-80f7-005056b8d207'
#  'e48f6c85-7414-e711-80c1-005056b8d207'
#  '56698c9e-35dd-ea11-80fc-005056b8d207'
#  '2c30ab69-847a-eb11-8110-005056b8d207']
# --------------------------------------------------
# Колонка : col1045
# Количество уникальных значений: 2
# Уникальные значения: ['project' 'apartment_description']
# --------------------------------------------------
# Колонка : col1046
# Количество уникальных значений: 4
# Уникальные значения: ['project' 'apartment_description' 'main'
#  'https://samolet.ru/spb/purchase/family/']
# --------------------------------------------------
# Колонка : col1047
# Количество уникальных значений: 6
# Уникальные значения: ['main' 'project' 'apartment_description'
#  'https://samolet.ru/purchase/family/'
#  'https://samolet.ru/spb/purchase/family/'
#  'https://samolet.ru/spb/it-mortgage/']
# --------------------------------------------------
# Колонка : col1048
# Количество уникальных значений: 13
# Уникальные значения: ['main' 'project' 'apartment_description'
#  'https://samolet.ru/ipoteka-001-7-years/'
#  'https://samolet.ru/it-mortgage/' 'https://samolet.ru/spb/it-mortgage/'
#  'https://samolet.ru/purchase/family/?utm_source=yandex_search&utm_medium=cpc&utm_campaign=samolet_yd_s_brand_spb_common_search_search_samolet_text_spb-lo_33~yzizmzuw|70577427&utm_term=%D1%81%D0%B0%D0%BC%D0%BE%D0%BB%D0%B5%D1%82%20%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D1%89%D0%B8%D0%BA%20%D1%81%D0%B0%D0%BD%D0%BA%D1%82%20%D0%BF%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3&utm_content=36157125856_|cid|70577427|gid|4800725314|aid|11670814675|adp|no|pos|premium1|src|search_none|dvc|mobile|reg|2|DOP_family&calltouch_tm=yd_c:70577427_gb:4800725314_ad:11670814675_ph:36157125856_st:search_pt:premium_p:1_s:none_dt:mobile_reg:2_ret:_apt:none&yclid=14491428404578484223'
#  'https://samolet.ru/ipoteka-001-7-years/?utm_source=vk&amp;utm_medium=messenger&amp;utm_campaign=gk_samolet_ipoteka_0_01_7_years_social-groups_realty_smart-banners_rf_0~ymiwyjf']
# --------------------------------------------------
# Колонка : col1053
# Количество уникальных значений: 3
# Уникальные значения: ['storage' 'project_ipoteka-2-99' 'araptment_ipoteka-2-99']
# --------------------------------------------------
# Колонка : col1054
# Количество уникальных значений: 5
# Уникальные значения: ['araptment_ipoteka-2-99' 'project_ipoteka-2-99' 'storage' 'main' 'family']
# --------------------------------------------------
# Колонка : col1055
# Количество уникальных значений: 6
# Уникальные значения: ['main' 'araptment_ipoteka-2-99' 'project_ipoteka-2-99' 'storage' 'family'
#  'it_mortgage']
# --------------------------------------------------
# Колонка : col1056
# Количество уникальных значений: 8
# Уникальные значения: ['main' 'araptment_ipoteka-2-99' 'project_ipoteka-2-99' 'ipoteka-001-7'
#  'parking' 'storage' 'family' 'it_mortgage']
# --------------------------------------------------
# Колонка : col1057
# Количество уникальных значений: 7
# Уникальные значения: ['parking' 'araptment_ipoteka-2-99' 'main' 'project_ipoteka-2-99'
#  'storage' 'family' 'ipoteka-001-7']
# --------------------------------------------------
# Колонка : col1058
# Количество уникальных значений: 7
# Уникальные значения: ['araptment_ipoteka-2-99' 'ipoteka-001-7' 'parking' 'project_ipoteka-2-99'
#  'main' 'storage' 'family']
# --------------------------------------------------
# Колонка : col1059
# Количество уникальных значений: 8
# Уникальные значения: ['main' 'araptment_ipoteka-2-99' 'ipoteka-001-7' 'project_ipoteka-2-99'
#  'parking' 'storage' 'family' 'it_mortgage']
# --------------------------------------------------
# Колонка : col1060
# Количество уникальных значений: 8
# Уникальные значения: ['main' 'araptment_ipoteka-2-99' 'project_ipoteka-2-99' 'ipoteka-001-7'
#  'family' 'storage' 'it_mortgage' 'parking']
# --------------------------------------------------
# Колонка : col1061
# Количество уникальных значений: 3
# Уникальные значения: ['other_mortgage_programs' 'form_ipoteka-2-99' 'mortgage_calc']
# --------------------------------------------------
# Колонка : col1062
# Количество уникальных значений: 5
# Уникальные значения: ['form_ipoteka-2-99' 'other_mortgage_programs' 'private_area_refinancing'
#  'mortgage_calc' 'top_offer']
# --------------------------------------------------
# Колонка : col1063
# Количество уникальных значений: 5
# Уникальные значения: ['form_ipoteka-2-99' 'other_mortgage_programs' 'top_offer'
#  'private_area_refinancing' 'mortgage_calc']
# --------------------------------------------------
# Колонка : col1064
# Количество уникальных значений: 5
# Уникальные значения: ['form_ipoteka-2-99' 'other_mortgage_programs' 'mortgage_calc' 'top_offer'
#  'private_area_refinancing']
# --------------------------------------------------
# Колонка : col1065
# Количество уникальных значений: 4
# Уникальные значения: ['other_mortgage_programs' 'form_ipoteka-2-99' 'top_offer' 'mortgage_calc']
# --------------------------------------------------
# Колонка : col1066
# Количество уникальных значений: 4
# Уникальные значения: ['form_ipoteka-2-99' 'mortgage_calc' 'other_mortgage_programs' 'top_offer']
# --------------------------------------------------
# Колонка : col1067
# Количество уникальных значений: 4
# Уникальные значения: ['form_ipoteka-2-99' 'other_mortgage_programs' 'mortgage_calc' 'top_offer']
# --------------------------------------------------
# Колонка : col1068
# Количество уникальных значений: 4
# Уникальные значения: ['form_ipoteka-2-99' 'other_mortgage_programs' 'mortgage_calc' 'top_offer']
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col1069'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 3
#       1 for colum  in Data_Test_Object.columns:
# ----> 3     unique_values = Data_Train_Object[colum].dropna().unique()
#       4     print(f"Колонка : {colum}")
#       5     print(f"Количество уникальных значений: {len(unique_values)}")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'col1069'

# %% [markdown]
# ### Потратив какое то время просмотрев и проанализировав текстовые колонки мы видим, что это
#  * ССылки
#  * указание Ипотеки и её тип
#  * Название ЖК
#  *  возможно mac-адрес оборудования
#
# ### Эти данные не помугут не нам не модели предугодать целевую переменную report_date попала в текст переведём их в формат даты и сохраним

# %%
Data_Train_Object["report_date"] = pd.to_datetime(Data_Train_Object["report_date"],  errors='coerce')

# %%
Data_Test_Object["report_date"] = pd.to_datetime(Data_Test_Object["report_date"],  errors='coerce')

# %%
colums_is_nul = Data_Train_numeric.isnull().mean() * 100 
columns_show = colums_is_nul[colums_is_nul > 0.99]

print("-" * 60)
print(f"Количество колонок в Test с более чем 99% пропусков: {len(columns_show)}")
# Out:
# ------------------------------------------------------------
# Количество колонок в Test с более чем 99% пропусков: 2273

# %%
colums_is_nul = Data_Test_numeric.isnull().mean() * 100 
columns_show = colums_is_nul[colums_is_nul > 0.99]

print("-" * 60)
print(f"Количество колонок в Train с более чем 99% пропусков: {len(columns_show)}")
# Out:
# ------------------------------------------------------------
# Количество колонок в Train с более чем 99% пропусков: 2094

# %% [markdown]
# Всё не радужно, заполнить с помощью среднего значения и медианой с ходу не получится, данных очень мало, и мы не знаем что может находиться в зашифрованных колонках, терять данные мы не можем так, что попробуем Заполнить пропуска с помощь импутера и удалим данные в которых отсутсвует полностью значния

# %%
columns_to_drop = Data_Train_numeric.columns[Data_Train_numeric.isnull().all()]
Data_Train_numeric = Data_Train_numeric.drop(columns=columns_to_drop)

# %%
columns_to_drop = Data_Test_numeric.columns[Data_Test_numeric.isnull().all()]
Data_Test_numeric = Data_Test_numeric.drop(columns=columns_to_drop)

# %% [markdown]
# Скорпируем на всякий датасет

# %%
Data_Train_filing =  Data_Train_numeric.copy()
Data_Tast_filing  =  Data_Test_numeric.copy()

# %% [markdown]
# Используем SimpleImputer из sklearn

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# Создадитм класс SimpleImputer и попробуем заполнить медианой

# %%
imputer = SimpleImputer(strategy='median', copy=False)

# %%
train_imputed_numerical = imputer.fit_transform(Data_Train_filing[Data_Train_filing.columns])

# %%
Train_imputed_numerical_df = pd.DataFrame(train_imputed_numerical, columns=Data_Train_filing.columns)

# %%
Train_imputed_numerical_df
# Out:
#        client_id  target  col1  col2  col3  col4       col5       col6  \
# 0            1.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 1            5.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 2            6.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 3            7.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 4            8.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# ...          ...     ...   ...   ...   ...   ...        ...        ...
# 14451     1241.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14452     1969.0     1.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14453     7116.0     1.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14454     7117.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14455      849.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
#
#             col7       col8  ...    col2654    col2655    col2656    col2657  \
# 0      3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# 1      3921976.0  3921976.0  ...  7616803.0  7616803.0  7616803.0  6322850.0
# 2      3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# 3      3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# 4      3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# ...          ...        ...  ...        ...        ...        ...        ...
# 14451  3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# 14452  3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# 14453  3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# 14454  3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
# 14455  3921976.0  3921976.0  ...  6240000.0  6164000.0  6224000.0  6322850.0
#
#          col2658    col2659    col2660    col2661    col2662   col2663
# 0      6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.256261
# 1      6322850.0  6322850.0  7616803.0  7616803.0  7616803.0  0.256261
# 2      6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.256261
# 3      6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.258682
# 4      6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.254164
# ...          ...        ...        ...        ...        ...       ...
# 14451  6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.276902
# 14452  6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.260516
# 14453  6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.260005
# 14454  6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.256261
# 14455  6322850.0  6322850.0  6244578.0  6146773.5  6225550.0  0.293904
#
# [14456 rows x 2238 columns]

# %%
Train_imputed_numerical_df.isnull().mean() * 100
# Out:
# client_id    0.0
# target       0.0
# col1         0.0
# col2         0.0
# col3         0.0
#             ...
# col2659      0.0
# col2660      0.0
# col2661      0.0
# col2662      0.0
# col2663      0.0
# Length: 2238, dtype: float64

# %% [markdown]
# Пропусков нет сделаем тоже самое для теста

# %%
test_imputed_numerical = imputer.fit_transform(Data_Tast_filing[Data_Tast_filing.columns])
Test_imputed_numerical_df = pd.DataFrame(test_imputed_numerical, columns=Data_Tast_filing.columns)

# %% [markdown]
# Теперь попробуем провизуализировать пропуски

# %%
#fig, ax = plt.subplots(figsize=(11, 11))
#sns.heatmap(Train_imputed_numerical_df.isnull(), cmap='cividis', cbar = False)

#plt.show()

# %%
colums_is_nul = Train_imputed_numerical_df.isnull().mean() * 100 
columns_show = colums_is_nul[colums_is_nul > 0.1]

print("-" * 60)
print(f"Количество колонок в Train с более чем 10% пропусков: {len(columns_show)}")
# Out:
# ------------------------------------------------------------
# Количество колонок в Train с более чем 10% пропусков: 0

# %%
columns_show
# Out:
# Series([], dtype: float64)

# %%
#fig, ax = plt.subplots(figsize=(11, 11))
#sns.heatmap(Test_imputed_numerical_df.isnull(), cmap='cividis', cbar = False)

#plt.show()

# %%
colums_is_nul = Test_imputed_numerical_df.isnull().mean() * 100 
columns_show = colums_is_nul[colums_is_nul > 0.1]

print("-" * 60)
print(f"Количество колонок в Train с более чем 10% пропусков: {len(columns_show)}")
# Out:
# ------------------------------------------------------------
# Количество колонок в Train с более чем 10% пропусков: 0

# %% [markdown]
# Пропуски по дате мы востановить не можем, так как мы не знаем даты, в который был сделан опрос нам проще избавиться от пробелов удалить эти данные

# %%
colums_is_nul = Train_imputed_numerical_df.isnull().mean() * 100 
columns_show = colums_is_nul[colums_is_nul > 0.1]

print("-" * 60)
print(f"Количество колонок в Train с более чем 10% пропусков: {len(columns_show)}")
# Out:
# ------------------------------------------------------------
# Количество колонок в Train с более чем 10% пропусков: 0

# %%
Train_imputed_numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14456 entries, 0 to 14455
# Columns: 2238 entries, client_id to col2663
# dtypes: float64(2238)
# memory usage: 246.8 MB

# %%
print(f"В Датафрейме Train_imputed_numerical_df Строк:{Train_imputed_numerical_df.shape[0]} Колонок: {Train_imputed_numerical_df.shape[1]}")
# Out:
# В Датафрейме Train_imputed_numerical_df Строк:14456 Колонок: 2238

# %%
Test_imputed_numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Columns: 2247 entries, client_id to col2663
# dtypes: float64(2247)
# memory usage: 62.4 MB

# %%
print(f"В Датафрейме Test_imputed_numerical_df Строк:{Test_imputed_numerical_df.shape[0]} Колонок: {Test_imputed_numerical_df.shape[1]}")
# Out:
# В Датафрейме Test_imputed_numerical_df Строк:3642 Колонок: 2247

# %% [markdown]
# Вернём report_date в датасеты

# %%
Data_Train = Train_imputed_numerical_df
Data_Train['report_date'] = Data_Train_Object["report_date"] 
Data_Train['year'] = Data_Train['report_date'].dt.year
Data_Train['month'] = Data_Train['report_date'].dt.month
Data_Train['day'] = Data_Train['report_date'].dt.day
Data_Train['day_of_week'] = Data_Train['report_date'].dt.dayofweek

# %%
Data_Test = Test_imputed_numerical_df
Data_Test['report_date'] = Data_Test_Object["report_date"] 
Data_Test['year'] = Data_Test['report_date'].dt.year
Data_Test['month'] = Data_Test['report_date'].dt.month
Data_Test['day'] = Data_Test['report_date'].dt.day
Data_Test['day_of_week'] = Data_Test['report_date'].dt.dayofweek

# %%
for df in [Data_Train, Data_Test]:
    datetime_columns = df.select_dtypes(include=['datetime64']).columns
    for col in datetime_columns:
        df[col] = df[col].astype('int64') // 10**9

# %%
Data_Train
# Out:
#        client_id  target  col1  col2  col3  col4       col5       col6  \
# 0            1.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 1            5.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 2            6.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 3            7.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 4            8.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# ...          ...     ...   ...   ...   ...   ...        ...        ...
# 14451     1241.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14452     1969.0     1.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14453     7116.0     1.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14454     7117.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
# 14455      849.0     0.0   0.0   0.5   0.0   0.0  7464071.0  7464071.0
#
#             col7       col8  ...    col2659    col2660    col2661    col2662  \
# 0      3921976.0  3921976.0  ...  6322850.0  6244578.0  6146773.5  6225550.0
# 1      3921976.0  3921976.0  ...  6322850.0  7616803.0  7616803.0  7616803.0
# 2      3921976.0  3921976.0  ...  6322850.0  6244578.0  6146773.5  6225550.0
# 3      3921976.0  3921976.0  ...  6322850.0  6244578.0  6146773.5  6225550.0
# 4      3921976.0  3921976.0  ...  6322850.0  6244578.0  6146773.5  6225550.0
# ...          ...        ...  ...        ...        ...        ...        ...
# 14451  3921976.0  3921976.0  ...  6322850.0  6244578.0  6146773.5  6225550.0
# 14452  3921976.0  3921976.0  ...  6322850.0  6244578.0  6146773.5  6225550.0
# 3637   3500000.0  0.256261   1680307200  2023      4    1            5
# 3638   6733329.5  0.256261   1680307200  2023      4    1            5
# 3639   6733329.5  0.256919   1677628800  2023      3    1            2
# 3640   6733329.5  0.257217   1677628800  2023      3    1            2
# 3641   1400000.0  0.285755   1682899200  2023      5    1            0
#
# [3642 rows x 2252 columns]

# %% [markdown]
# Подгоним датасеты под одну размерность

# %%
Data_Test = Data_Test.reindex(columns=Data_Train.columns, fill_value=0)

# %%
print(f"В Датафрейме Data_Test Строк:{Data_Test.shape[0]} Колонок: {Data_Test.shape[1]}")
# Out:
# В Датафрейме Data_Test Строк:3642 Колонок: 2243

# %%
print(f"В Датафрейме Data_Train Строк:{Data_Train.shape[0]} Колонок: {Data_Train.shape[1]}")
# Out:
# В Датафрейме Data_Train Строк:14456 Колонок: 2243

# %% [markdown]
# Проверим отсутсующие значение после конкатинации

# %%
null_values =  Data_Train.isnull().sum().sum()
print(null_values)
# Out:
# 0

# %%
null_values =  Data_Test.isnull().sum().sum()
print(null_values)
# Out:
# 0

# %% [markdown]
# Разделим данные отделив целевую переменную

# %%
X_train = Data_Train.drop(columns="target", axis=1)
y_train = Data_Train["target"]

# %%
X_test = Data_Test.drop(columns="target", axis = 1)
y_test  = Data_Test["target"]

# %% [markdown]
# И возьмём Класcическую модель Логистической регрессии

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Смаштабируем признаки

# %%
scaler = StandardScaler()

# %%
scaler_X_train = scaler.fit_transform(X_train)

# %%
scaler_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Создадим класс модели

# %%
Log_Model = LogisticRegression( class_weight='balanced', random_state=42, max_iter=1000)

# %%
Log_Model.fit(scaler_X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
Log_Model.coef_
# Out:
# array([[ 0.39465342, -0.01211206,  0.01242638, ..., -0.1264756 ,
#          0.        ,  0.01504704]])

# %%
y_pred = Log_Model.predict(scaler_X_test)

# %%
y_pred
# Out:
# array([1., 1., 1., ..., 1., 1., 0.])

# %%
y_pred_proba = Log_Model.predict_proba(scaler_X_test)

# %%
y_pred_proba
# Out:
# array([[0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        ...,
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 1.06559538e-15]])

# %% [markdown]
# Провидём оценку Модели

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.022789676002196595

# %% [markdown]
# Предсказание модели давольно плохое

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.01      0.01      3576
#          1.0       0.02      0.98      0.04        66
#
#     accuracy                           0.02      3642
#    macro avg       0.48      0.49      0.02      3642
# weighted avg       0.93      0.02      0.01      3642

# %% [markdown]
# support давольно плохая разбалансировка классов

# %% [markdown]
# Взгянем на ROC

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, accuracy_score, roc_curve, auc, roc_auc_score

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC-AUC (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='darkcyan', lw=2, linestyle='--')
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.title('Receiver Operating Characteristic(RandomForestClassifier)')
plt.legend(loc='lower right')
plt.show()

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Точность модели: {accuracy:.2f}")

roc_auc = roc_auc_score(y_test, y_pred)
print(f"ROC-AUC: {roc_auc:.2f}")
# Out:
# Точность модели: 0.02
# ROC-AUC: 0.49

# %% [markdown]
# Давольно плохое предсказание и модель не очень себя показывает Давайте попробуем другую модель

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-c
0 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.5/101.7 MB 8.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 87.0/101.7 MB 8.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 87.3/101.7 MB 9.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 87.8/101.7 MB 9.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 88.2/101.7 MB 9.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 88.6/101.7 MB 9.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.0/101.7 MB 9.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.4/101.7 MB 9.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.9/101.7 MB 9.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 90.3/101.7 MB 9.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 90.8/101.7 MB 9.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 91.2/101.7 MB 9.4 MB/s eta 0:00:02
#    ------------------------------------ --- 91.7/101.7 MB 9.4 MB/s eta 0:00:02
#    ------------------------------------ --- 92.2/101.7 MB 9.5 MB/s eta 0:00:02
#    ------------------------------------ --- 92.6/101.7 MB 9.5 MB/s eta 0:00:01
#    ------------------------------------ --- 93.0/101.7 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 93.6/101.7 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 94.0/101.7 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------- -- 94.4/101.7 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------- -- 95.0/101.7 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------- -- 95.4/101.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 96.0/101.7 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------- -- 96.5/101.7 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 96.8/101.7 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 97.4/101.7 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 97.8/101.7 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 98.2/101.7 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 98.8/101.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  99.2/101.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  99.6/101.7 MB 10.1 MB/s eta 0:00:01
#    --------------------------------------  100.0/101.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  100.4/101.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  100.8/101.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  101.3/101.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  101.6/101.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  101.7/101.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  101.7/101.7 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 101.7/101.7 MB 9.0 MB/s eta 0:00:00
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ---------------------------------------- 47.1/47.1 kB ? eta 0:00:00
# Installing collected packages: graphviz, catboost
# Successfully installed catboost-1.2.7 graphviz-0.20.3

# %%
from catboost import CatBoostClassifier

# %%
Log_Model2= CatBoostClassifier(
    depth=5,
    learning_rate=0.1,
    iterations=500,
    random_seed=42,
    verbose=0,  # Suppress training output
    l2_leaf_reg=3,
    min_data_in_leaf=10)

# %%
Log_Model2.fit(scaler_X_train, y_train )

# %%
y_proba_model2 = Log_Model2.predict_proba(scaler_X_test)[:, 1]

# %%
roc_auc = roc_auc_score(y_test, y_proba_model2)

# %%
print(f'ROC-AUC: {roc_auc}')
# Out:
# ROC-AUC: 0.8035387431360586

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_proba_model2)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC-AUC (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='darkcyan', lw=2, linestyle='--')
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.title('Receiver Operating Characteristic(RandomForestClassifier)')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Результат гараздо лучше

# %% [markdown]
# Давайте глянем ещё одну модель

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Log_Model3= RandomForestClassifier(
    n_estimators=500,      # Number of trees
    max_depth=5,           # Maximum depth of the tree
    min_samples_leaf=10,   # Minimum number of samples in a leaf
    random_state=42        # Ensures reproducibility
)

# %% [markdown]
# Обучим модель

# %%
Log_Model3.fit(scaler_X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=10, n_estimators=500,
#                        random_state=42)

# %%
y_prob_model3 = Log_Model3.predict_proba(scaler_X_test)[:, 1]

# %%
ROC_Model3 = roc_auc_score(y_test, y_prob_model3)

# %%
print(f'ROC-AUC: {ROC_Model3}')
# Out:
# ROC-AUC: 0.7420005423361128

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob_model3)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC-AUC (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='darkcyan', lw=2, linestyle='--')
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.title('Receiver Operating Characteristic(RandomForestClassifier)')
plt.legend(loc='lower right')
plt.show()

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.3-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\lostbuddha\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\lostbuddha\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-2.1.3-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/124.9 MB 544.7 kB/s eta 0:03:50
#    ---------------------------------------- 0.1/124.9 MB 726.2 kB/s eta 0:02:52
#    ---------------------------------------- 0.1/124.9 MB 774.0 kB/s eta 0:02:42
#    ---------------------------------------- 0.3/124.9 MB 1.4 MB/s eta 0:01:32
#    ---------------------------------------- 0.4/124.9 MB 1.3 MB/s eta 0:01:33
#    ---------------------------------------- 0.7/124.9 MB 2.2 MB/s eta 0:00:57
#    ---------------------------------------- 0.9/124.9 MB 2.5 MB/s eta 0:00:51
#    ---------------------------------------- 1.2/124.9 MB 3.0 MB/s eta 0:00:41
#     --------------------------------------- 1.6/124.9 MB 3.5 MB/s eta 0:00:36
#     --------------------------------------- 1.9/124.9 MB 3.8 MB/s eta 0:00:33
#     --------------------------------------- 2.2/124.9 MB 4.1 MB/s eta 0:00:31
#     --------------------------------------- 2.6/124.9 MB 4.4 MB/s eta 0:00:28
#     --------------------------------------- 3.0/124.9 MB 4.7 MB/s eta 0:00:26
#    - -------------------------------------- 3.4/124.9 MB 5.0 MB/s eta 0:00:25
#    - -------------------------------------- 3.8/124.9 MB 5.2 MB/s eta 0:00:24
#    - -------------------------------------- 4.2/124.9 MB 5.3 MB/s eta 0:00:23
#    - -------------------------------------- 4.5/124.9 MB 5.5 MB/s eta 0:00:23
#    - -------------------------------------- 5.1/124.9 MB 5.8 MB/s eta 0:00:21
#    - -------------------------------------- 5.5/124.9 MB 6.0 MB/s eta 0:00:20
#    - -------------------------------------- 5.9/124.9 MB 6.1 MB/s eta 0:00:20
#    -- ------------------------------------- 6.3/124.9 MB 6.2 MB/s eta 0:00:20
#    -- ------------------------------------- 6.6/124.9 MB 6.3 MB/s eta 0:00:19
#    -- ------------------------------------- 7.1/124.9 MB 6.4 MB/s eta 0:00:19
#    -- ------------------------------------- 7.5/124.9 MB 6.6 MB/s eta 0:00:18
#    -- ------------------------------------- 7.9/124.9 MB 6.6 MB/s eta 0:00:18
#    -- ------------------------------------- 8.3/124.9 MB 6.7 MB/s eta 0:00:18
#    -- ------------------------------------- 8.8/124.9 MB 6.8 MB/s eta 0:00:17
#    -- ------------------------------------- 9.3/124.9 MB 7.0 MB/s eta 0:00:17
#    --- ------------------------------------ 9.7/124.9 MB 7.1 MB/s eta 0:00:17
#    ------------- -------------------------- 42.2/124.9 MB 9.1 MB/s eta 0:00:10
#    ------------- -------------------------- 42.5/124.9 MB 9.1 MB/s eta 0:00:10
#    ------------- -------------------------- 43.0/124.9 MB 9.0 MB/s eta 0:00:10
#    ------------- -------------------------- 43.4/124.9 MB 9.0 MB/s eta 0:00:10
#    -------------- ------------------------- 43.8/124.9 MB 8.8 MB/s eta 0:00:10
#    -------------- ------------------------- 44.2/124.9 MB 8.8 MB/s eta 0:00:10
#    -------------- ------------------------- 44.6/124.9 MB 8.7 MB/s eta 0:00:10
#    -------------- ------------------------- 45.0/124.9 MB 9.0 MB/s eta 0:00:09
#    -------------- ------------------------- 45.4/124.9 MB 9.0 MB/s eta 0:00:09
#    -------------- ------------------------- 45.9/124.9 MB 8.8 MB/s eta 0:00:09
#    -------------- ------------------------- 46.3/124.9 MB 8.8 MB/s eta 0:00:09
#    -------------- ------------------------- 46.7/124.9 MB 8.8 MB/s eta 0:00:09
#    --------------- ------------------------ 47.2/124.9 MB 9.0 MB/s eta 0:00:09
#    --------------- ------------------------ 47.5/124.9 MB 8.8 MB/s eta 0:00:09
#    --------------- ------------------------ 47.9/124.9 MB 8.7 MB/s eta 0:00:09
#    --------------- ------------------------ 48.3/124.9 MB 8.8 MB/s eta 0:00:09
#    --------------- ------------------------ 48.7/124.9 MB 8.8 MB/s eta 0:00:09
#    --------------- ------------------------ 49.1/124.9 MB 8.8 MB/s eta 0:00:09
#    --------------- ------------------------ 49.5/124.9 MB 8.8 MB/s eta 0:00:09
#    --------------- ------------------------ 49.9/124.9 MB 8.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 50.3/124.9 MB 8.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 50.7/124.9 MB 8.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 51.1/124.9 MB 8.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 51.6/124.9 MB 8.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 51.9/124.9 MB 8.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 52.4/124.9 MB 9.0 MB/s eta 0:00:09
#    ---------------- ----------------------- 52.8/124.9 MB 9.0 MB/s eta 0:00:09
#    ----------------- ---------------------- 53.1/124.9 MB 9.0 MB/s eta 0:00:09
#    ----------------- ---------------------- 53.5/124.9 MB 8.8 MB/s eta 0:00:09
#    ----------------- ---------------------- 54.0/124.9 MB 9.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 54.2/124.9 MB 8.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 54.6/124.9 MB 8.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 55.0/124.9 MB 8.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 55.4/124.9 MB 8.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 55.8/124.9 MB 8.7 MB/s eta 0:00:08
#    ------------------ --------------------- 56.2/124.9 MB 8.7 MB/s eta 0:00:08
#    ------------------ --------------------- 56.7/124.9 MB 8.7 MB/s eta 0:00:08
MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.3

# %%
from xgboost import XGBClassifier

# %%
Log_Model4 = XGBClassifier(
    max_depth=5,#глубина дерева
    learning_rate=0.1,#Скорость обучения
    n_estimators=200,#количество итераций бустинга
    objective='binary:logistic', # задача бинарной классификации, где результатом является вероятность (логистическая регрессия).
    subsample=0.8,#Доля случайно выбранных обучающих образцов для построения каждого дерева.
    colsample_bytree=0.8, #Доля случайно выбранных признаков для построения каждого дерева
    reg_alpha=0.1,#т штраф за абсолютные значения весов листьев,
    reg_lambda=0.3, #Добавляет штраф за квадраты значений весов листьев
    random_state=42,#Устанавливает случайное начальное значение для обеспечения воспроизводимости результатов.
    eval_metric="auc"#Определяет метрику оценки для отслеживания производительности модели во время обучения.
)

# %%
Log_Model4.fit(scaler_X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_prob_Model4 = Log_Model4.predict_proba(scaler_X_test)[:, 1]

# %%
ROC_Model4 = roc_auc_score(y_test, y_prob_Model4)

# %%
print(f'ROC-AUC: {ROC_Model4}')
# Out:
# ROC-AUC: 0.8125169480035253

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob_Model4)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC-AUC (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='darkcyan', lw=2, linestyle='--')
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.title('Receiver Operating Characteristic(RandomForestClassifier)')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Попробуем подобрать Гипер параметры длдя последней модели c помощью RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# %% [markdown]
# Гиперпараметры для случайного перебора

# %%
param_dist = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': np.linspace(0, 1, 5),
    'reg_lambda': np.linspace(0, 1, 5)
}

# %%
Log_Model5 = XGBClassifier(objective='binary:logistic', eval_metric="auc", random_state=42)

# %% [markdown]
# Настройка RandomizedSearchCV

# %%
random_search = RandomizedSearchCV(
    estimator=Log_Model5,
    param_distributions=param_dist,
    n_iter=50,          # Количество случайных комбинаций
    scoring='roc_auc',  # Оценка по метрике ROC-AUC
    cv=3,               # Кросс-валидация с 3 фолдами
    verbose=2,          # Показывать процесс поиска
    n_jobs=-1,          # Использовать все процессоры
    random_state=42     # Для воспроизводимости
)

# %%
random_search.fit(scaler_X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='auc',
#                                            feature_types=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rat...
#                                            num_parallel_tree=None,
#                                            random_state=42, ...),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'learning_rate': [0.01, 0.1, 0.2],
#                                         'max_depth': [3, 5, 7],
#                                         'n_estimators': [100, 200, 300],
#                                         'reg_alpha': array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#                                         'reg_lambda': array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=42, scoring='roc_auc', verbose=2)

# %%
print("Лучшие параметры:", random_search.best_params_)
print("Лучший ROC-AUC:", random_search.best_score_)
# Out:
# Лучшие параметры: {'subsample': 1.0, 'reg_lambda': 0.25, 'reg_alpha': 1.0, 'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 1.0}
# Лучший ROC-AUC: 0.9584818134807311

# %%
Final_Model = XGBClassifier(
    max_depth=7,#глубина дерева
    learning_rate=0.1,#Скорость обучения
    n_estimators=300,#количество итераций бустинга
    objective='binary:logistic', # задача бинарной классификации, где результатом является вероятность (логистическая регрессия).
    subsample=1.0,#Доля случайно выбранных обучающих образцов для построения каждого дерева.
    colsample_bytree=1.0, #Доля случайно выбранных признаков для построения каждого дерева
    reg_alpha=1.0,#т штраф за абсолютные значения весов листьев,
    reg_lambda=0.25, #Добавляет штраф за квадраты значений весов листьев
    random_state=42,#Устанавливает случайное начальное значение для обеспечения воспроизводимости результатов.
    eval_metric="auc"#Определяет метрику оценки для отслеживания производительности модели во время обучения.
)

# %%
Final_Model.fit(scaler_X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[401], line 1
# ----> 1 Final_Model.fit(scaler_X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:2100, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
# -> 2100     _check_call(
#    2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:284, in _check_call(ret)
#     273 """Check the return value of C API call
#     274
#     275 This function will raise exception when error occurs.
#    (...)
#     281     return value from API calls
#     282 """
#     283 if ret != 0:
# --> 284     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [18:47:05] C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\metric\metric.cc:49: Unknown metric function roc_auc

# %%
Final_proba = Final_Model.predict_proba(scaler_X_test)[:, 1]

Final_ROC = roc_auc_score(y_test, Final_proba)

# %%
Final_ROC
# Out:
# 0.7896668022506947
